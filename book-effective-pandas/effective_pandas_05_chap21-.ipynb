# %% [markdown]
# # Chapter 21

# %% [markdown]
# ## 21.1

# %%
import pandas as pd

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/2020-jetbrains-python-survey.csv'

# %%
jb = pd.read_csv(url)
jb
# Out:
# C:\Users\tmadsen\AppData\Local\Temp\ipykernel_2148\3648050692.py:1: DtypeWarning: Columns (152) have mixed types. Specify dtype option on import or set low_memory=False.
#   jb = pd.read_csv(url)
#       is.python.main other.lang.None other.lang.Java other.lang.JavaScript  \
# 0                Yes             NaN             NaN                   NaN
# 1                Yes             NaN            Java            JavaScript
# 2                Yes             NaN             NaN                   NaN
# 3                Yes             NaN             NaN            JavaScript
# 4                Yes             NaN            Java            JavaScript
# ...              ...             ...             ...                   ...
# 54457            Yes             NaN             NaN                   NaN
# 54458            Yes             NaN             NaN            JavaScript
# 54459            Yes             NaN             NaN            JavaScript
# ...
