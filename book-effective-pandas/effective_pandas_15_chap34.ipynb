# %% [markdown]
# # Chapter 34 - Styling Dataframes

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import sparklines

# %% [markdown]
# ## 34.1 Loading the Data

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/dirtydevil.txt'
df = pd.read_csv(url, skiprows=lambda num: num <34 or num==35, sep='\t')
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_99193/2013143809.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url, skiprows=lambda num: num <34 or num==35, sep='\t')

# %%
def tweak_river(df_):
    return (df_
            .assign(datetime=pd.to_datetime(df_.datetime))
            .rename(columns={'144166_00060': 'cfs',
                             '144167_00065': 'gage_height'})
            .set_index('datetime')
            )

# %%
dd = tweak_river(df)
dd
# Out:
#                     agency_cd  site_no tz_cd    cfs 144166_00060_cd  \
# datetime
# 2001-05-07 01:00:00      USGS  9333500   MDT  71.00          A:[91]
# 2001-05-07 01:15:00      USGS  9333500   MDT  71.00          A:[91]
# 2001-05-07 01:30:00      USGS  9333500   MDT  71.00          A:[91]
# 2001-05-07 01:45:00      USGS  9333500   MDT  70.00          A:[91]
# 2001-05-07 02:00:00      USGS  9333500   MDT  70.00          A:[91]
# ...                       ...      ...   ...    ...             ...
# 2020-09-28 08:30:00      USGS  9333500   MDT   9.53               P
# 2020-09-28 08:45:00      USGS  9333500   MDT   9.20               P
# 2020-09-28 09:00:00      USGS  9333500   MDT   9.20               P
# 2020-09-28 09:15:00      USGS  9333500   MDT   9.20               P
# 2020-09-28 09:30:00      USGS  9333500   MDT   9.20               P
#
#                      gage_height 144167_00065_cd
# datetime
# 2001-05-07 01:00:00          NaN             NaN
# 2001-05-07 01:15:00          NaN             NaN
# 2001-05-07 01:30:00          NaN             NaN
# 2001-05-07 01:45:00          NaN             NaN
# 2001-05-07 02:00:00          NaN             NaN
# ...                          ...             ...
# 2020-09-28 08:30:00         6.16               P
# 2020-09-28 08:45:00         6.15               P
# 2020-09-28 09:00:00         6.15               P
# 2020-09-28 09:15:00         6.15               P
# 2020-09-28 09:30:00         6.15               P
#
# [539305 rows x 7 columns]

# %%
agg_flow = (dd
            .groupby(pd.Grouper(freq='M'))
            .agg(cfs=('cfs', 'median'),
                 total_flow=('cfs', lambda ser: (ser*15*60).sum()),
                 gage_height=('gage_height', 'median'),
                 flow_trend=('cfs', lambda ser: sparklines.sparklines(
                     ser
                     .fillna(0)
                     .resample('2D')
                     .median()
                     .fillna(0))
                    [0])
                 )
            .assign(quarterly_flow=lambda df_: df_
                    .total_flow
                    .resample('Q')
                    .transform('sum'),
                    percent_quarterly_flow=lambda df2_: df2_
                    .total_flow / df2_.quarterly_flow,
                    off_goal=lambda df3_: df3_.percent_quarterly_flow - 0.33,
                    cost=lambda df4_: df4_.total_flow * 0.0002
                    )
            )

# %%
agg_flow
# Out:
#               cfs   total_flow  gage_height        flow_trend  quarterly_flow  \
# datetime
# 2001-05-31  47.00  105383700.0          NaN     █▅▅▃▅▄▄▃▂▃▂▁▁     123227100.0
# 2001-06-30  23.00   17843400.0          NaN   █▇▆▄▁▁▁▁▁▁▁▁▁▁▆     123227100.0
# 2001-07-31  17.00    7781400.0          NaN               ▁█▄     243448920.0
# 2001-08-31  52.50  192848220.0          NaN             █▂▁▁▁     243448920.0
# 2001-09-30  26.00   42819300.0          NaN     ▆▆▁▁▅▆▁██▆▆▆▆     243448920.0
# ...           ...          ...          ...               ...             ...
# 2020-05-31  21.25   60721029.0         6.51  ▇▅▇▆▅▆█▆▄▃▃▃▃▂▂▁     262374219.0
# 2020-06-30  10.20   24475410.0         6.28   ▄▅▅▅██▆▄▁▁▁▁▁▁▁     262374219.0
# 2020-07-31  10.80   67073337.0         6.05  ▁▁▁▁▂▂▂▂▂▂▂▂█▅█▅      88485345.0
# 2020-08-31   0.32   11042316.0         5.48  █▅▄▃▂▁▁▁▁▁▁▁▁▁▁▁      88485345.0
# 2020-09-30   5.79   10369692.0         6.01    ▁▁▁▁▁▁▅▅▅▅▆▇██      88485345.0
#
#             percent_quarterly_flow  off_goal        cost
# datetime
# 2001-05-31                0.855199  0.525199  21076.7400
# 2001-06-30                0.144801 -0.185199   3568.6800
# 2001-07-31                0.031963 -0.298037   1556.2800
# 2001-08-31                0.792151  0.462151  38569.6440
# 2001-09-30                0.175886 -0.154114   8563.8600
# ...                            ...       ...         ...
# 2020-05-31                0.231429 -0.098571  12144.2058
# 2020-06-30                0.093284 -0.236716   4895.0820
# 2020-07-31                0.758016  0.428016  13414.6674
# 2020-08-31                0.124793 -0.205207   2208.4632
# 2020-09-30                0.117191 -0.212809   2073.9384
#
# [233 rows x 8 columns]

# %% [markdown]
# ## 34.2 Sparklines

# %%
sparklines.sparklines(range(10))[0]
# Out:
# '▁▂▃▃▄▅▆▆▇█'

# %%
agg_flow.flow_trend
# Out:
# datetime
# 2001-05-31       █▅▅▃▅▄▄▃▂▃▂▁▁
# 2001-06-30     █▇▆▄▁▁▁▁▁▁▁▁▁▁▆
# 2001-07-31                 ▁█▄
# 2001-08-31               █▂▁▁▁
# 2001-09-30       ▆▆▁▁▅▆▁██▆▆▆▆
#                     ...
# 2020-05-31    ▇▅▇▆▅▆█▆▄▃▃▃▃▂▂▁
# 2020-06-30     ▄▅▅▅██▆▄▁▁▁▁▁▁▁
# 2020-07-31    ▁▁▁▁▂▂▂▂▂▂▂▂█▅█▅
# 2020-08-31    █▅▄▃▂▁▁▁▁▁▁▁▁▁▁▁
# 2020-09-30      ▁▁▁▁▁▁▅▅▅▅▆▇██
# Freq: M, Name: flow_trend, Length: 233, dtype: object

# %% [markdown]
# ## 34.3 The `.style` Attribute

# %%
(agg_flow
 .reset_index()
 .style
 .format({'cost': '${:,.2f}', 'datetime': '{:%Y/%m}/01',
          'percent_quarterly_flow': '{:.1%}',
          'off_goal': '{:+.1%}',
          **{col: '{:.1f}' for col in ['cfs', 'total_flow', 'quarterly_flow']}},
         na_rep='Missing')
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0dcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0dcf_level0_col0" class="col_heading level0 col0" >datetime</th>
#       <th id="T_d0dcf_level0_col1" class="col_heading level0 col1" >cfs</th>
#       <th id="T_d0dcf_level0_col2" class="col_heading level0 col2" >total_flow</th>
#       <th id="T_d0dcf_level0_col3" class="col_heading level0 col3" >gage_height</th>
#       <th id="T_d0dcf_level0_col4" class="col_heading level0 col4" >flow_trend</th>
#       <th id="T_d0dcf_level0_col5" class="col_heading level0 col5" >quarterly_flow</th>
#       <th id="T_d0dcf_level0_col6" class="col_heading level0 col6" >percent_quarterly_flow</th>
#       <th id="T_d0dcf_level0_col7" class="col_heading level0 col7" >off_goal</th>
#       <th id="T_d0dcf_level0_col8" class="col_heading level0 col8" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0dcf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0dcf_row0_col0" class="data row0 col0" >2001/05/01</td>
#       <td id="T_d0dcf_row0_col1" class="data row0 col1" >47.0</td>
#       <td id="T_d0dcf_row0_col2" class="data row0 col2" >105383700.0</td>
#       <td id="T_d0dcf_row0_col3" class="data row0 col3" >Missing</td>
#       <td id="T_d0dcf_row0_col4" class="data row0 col4" >█▅▅▃▅▄▄▃▂▃▂▁▁</td>
#       <td id="T_d0dcf_row0_col5" class="data row0 col5" >123227100.0</td>
#       <td id="T_d0dcf_row0_col6" class="data row0 col6" >85.5%</td>
#       <td id="T_d0dcf_row0_col7" class="data row0 col7" >+52.5%</td>
#       <td id="T_d0dcf_row0_col8" class="data row0 col8" >$21,076.74</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0dcf_row1_col0" class="data row1 col0" >2001/06/01</td>
#       <td id="T_d0dcf_row1_col1" class="data row1 col1" >23.0</td>
#       <td id="T_d0dcf_row1_col2" class="data row1 col2" >17843400.0</td>
#       <td id="T_d0dcf_row1_col3" class="data row1 col3" >Missing</td>
#       <td id="T_d0dcf_row1_col4" class="data row1 col4" >█▇▆▄▁▁▁▁▁▁▁▁▁▁▆</td>
#       <td id="T_d0dcf_row1_col5" class="data row1 col5" >123227100.0</td>
#       <td id="T_d0dcf_row1_col6" class="data row1 col6" >14.5%</td>
#       <td id="T_d0dcf_row1_col7" class="data row1 col7" >-18.5%</td>
#       <td id="T_d0dcf_row1_col8" class="data row1 col8" >$3,568.68</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0dcf_row2_col0" class="data row2 col0" >2001/07/01</td>
#       <td id="T_d0dcf_row2_col1" class="data row2 col1" >17.0</td>
#       <td id="T_d0dcf_row2_col2" class="data row2 col2" >7781400.0</td>
#       <td id="T_d0dcf_row2_col3" class="data row2 col3" >Missing</td>
#       <td id="T_d0dcf_row2_col4" class="data row2 col4" >▁█▄</td>
#       <td id="T_d0dcf_row2_col5" class="data row2 col5" >243448920.0</td>
#       <td id="T_d0dcf_row2_col6" class="data row2 col6" >3.2%</td>
#       <td id="T_d0dcf_row2_col7" class="data row2 col7" >-29.8%</td>
#       <td id="T_d0dcf_row2_col8" class="data row2 col8" >$1,556.28</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0dcf_row3_col0" class="data row3 col0" >2001/08/01</td>
#       <td id="T_d0dcf_row3_col1" class="data row3 col1" >52.5</td>
#       <td id="T_d0dcf_row3_col2" class="data row3 col2" >192848220.0</td>
#       <td id="T_d0dcf_row3_col3" class="data row3 col3" >Missing</td>
#       <td id="T_d0dcf_row3_col4" class="data row3 col4" >█▂▁▁▁</td>
#       <td id="T_d0dcf_row3_col5" class="data row3 col5" >243448920.0</td>
#       <td id="T_d0dcf_row3_col6" class="data row3 col6" >79.2%</td>
#       <td id="T_d0dcf_row3_col7" class="data row3 col7" >+46.2%</td>
#       <td id="T_d0dcf_row3_col8" class="data row3 col8" >$38,569.64</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0dcf_row4_col0" class="data row4 col0" >2001/09/01</td>
#       <td id="T_d0dcf_row4_col1" class="data row4 col1" >26.0</td>
#       <td id="T_d0dcf_row4_col2" class="data row4 col2" >42819300.0</td>
#       <td id="T_d0dcf_row4_col3" class="data row4 col3" >Missing</td>
#       <td id="T_d0dcf_row4_col4" class="data row4 col4" >▆▆▁▁▅▆▁██▆▆▆▆</td>
#       <td id="T_d0dcf_row4_col5" class="data row4 col5" >243448920.0</td>
#       <td id="T_d0dcf_row4_col6" class="data row4 col6" >17.6%</td>
#       <td id="T_d0dcf_row4_col7" class="data row4 col7" >-15.4%</td>
#       <td id="T_d0dcf_row4_col8" class="data row4 col8" >$8,563.86</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d0dcf_row5_col0" class="data row5 col0" >2001/10/01</td>
#       <td id="T_d0dcf_row5_col1" class="data row5 col1" >54.0</td>
#       <td id="T_d0dcf_row5_col2" class="data row5 col2" >134975700.0</td>
#       <td id="T_d0dcf_row5_col3" class="data row5 col3" >Missing</td>
#       <td id="T_d0dcf_row5_col4" class="data row5 col4" >▁▁▂▂▃▄▄▅▅▅▆▇▇▇█</td>
#       <td id="T_d0dcf_row5_col5" class="data row5 col5" >480483900.0</td>
#       <td id="T_d0dcf_row5_col6" class="data row5 col6" >28.1%</td>
#       <td id="T_d0dcf_row5_col7" class="data row5 col7" >-4.9%</td>
#       <td id="T_d0dcf_row5_col8" class="data row5 col8" >$26,995.14</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d0dcf_row6_col0" class="data row6 col0" >2001/11/01</td>
#       <td id="T_d0dcf_row6_col1" class="data row6 col1" >104.0</td>
#       <td id="T_d0dcf_row6_col2" class="data row6 col2" >203110200.0</td>
#       <td id="T_d0dcf_row6_col3" class="data row6 col3" >Missing</td>
#       <td id="T_d0dcf_row6_col4" class="data row6 col4" >▆▆▆▆▆▇▇▇██▁▁▁▇▇</td>
#       <td id="T_d0dcf_row6_col5" class="data row6 col5" >480483900.0</td>
#       <td id="T_d0dcf_row6_col6" class="data row6 col6" >42.3%</td>
#       <td id="T_d0dcf_row6_col7" class="data row6 col7" >+9.3%</td>
#       <td id="T_d0dcf_row6_col8" class="data row6 col8" >$40,622.04</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d0dcf_row7_col0" class="data row7 col0" >2001/12/01</td>
#       <td id="T_d0dcf_row7_col1" class="data row7 col1" >115.0</td>
#       <td id="T_d0dcf_row7_col2" class="data row7 col2" >142398000.0</td>
#       <td id="T_d0dcf_row7_col3" class="data row7 col3" >Missing</td>
#       <td id="T_d0dcf_row7_col4" class="data row7 col4" >▆▁▁▁▇▇▁▁▁▆▆▆▁▆▇█</td>
#       <td id="T_d0dcf_row7_col5" class="data row7 col5" >480483900.0</td>
#       <td id="T_d0dcf_row7_col6" class="data row7 col6" >29.6%</td>
#       <td id="T_d0dcf_row7_col7" class="data row7 col7" >-3.4%</td>
#       <td id="T_d0dcf_row7_col8" class="data row7 col8" >$28,479.60</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d0dcf_row8_col0" class="data row8 col0" >2002/01/01</td>
#       <td id="T_d0dcf_row8_col1" class="data row8 col1" >136.0</td>
#       <td id="T_d0dcf_row8_col2" class="data row8 col2" >197745300.0</td>
#       <td id="T_d0dcf_row8_col3" class="data row8 col3" >Missing</td>
#       <td id="T_d0dcf_row8_col4" class="data row8 col4" >██▇███▇▇▁▁▁▁▁▁▇</td>
#       <td id="T_d0dcf_row8_col5" class="data row8 col5" >638525700.0</td>
#       <td id="T_d0dcf_row8_col6" class="data row8 col6" >31.0%</td>
#       <td id="T_d0dcf_row8_col7" class="data row8 col7" >-2.0%</td>
#       <td id="T_d0dcf_row8_col8" class="data row8 col8" >$39,549.06</td>
#     </tr>
#     <tr>
#       <th id="T_d0dcf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d0dcf_row9_col0" class="data row9 col0" >2002/02/01</td>
#       <td id="T_d0dcf_row9_col1" class="data row9 col1" >131.0</td>
#       <td id="T_d0dcf_row9_col2" class="data row9 col2" >157920300.0</td>
#       <td id="T_d0dcf_row9_col3" class="data row9 col3" >Missing</td>
#       <td id="T_d0dcf_row9_col4" class="data row9 col4" >▄▄█▆▆█▁</td>
#       <td id="T_d0dcf_row9_col5

# %% [markdown]
# ## 34.4 Formatting
# ## 34.5 Embedding Bar Plots
# ## 34.6 Highlighting

# %%
(agg_flow
 .reset_index()
 .style
 .format({'cost': '${:,.2f}', 'datetime': '{:%Y/%m}/01',
          'percent_quarterly_flow': '{:.1%}',
          'off_goal': '{:+.1%}',
          **{col: '{:.1f}' for col in ['cfs', 'total_flow', 'quarterly_flow']}},
         na_rep='Missing')
 .bar(subset='cfs', color='#c07fef', vmax=agg_flow.cfs.quantile(.95))
 .bar(subset='off_goal', color=['red','green'], align='mid')
 .highlight_null(null_color='#fef70c')
 .highlight_max(axis=0, color='green')
 )
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_99193/2245464122.py:11: FutureWarning: `null_color` is deprecated: use `color` instead
#   .highlight_null(null_color='#fef70c')
# <style type="text/css">
# #T_1c9af_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 32.2%, transparent 32.2%);
# }
# #T_1c9af_row0_col3, #T_1c9af_row1_col3, #T_1c9af_row2_col3, #T_1c9af_row3_col3, #T_1c9af_row4_col3, #T_1c9af_row5_col3, #T_1c9af_row6_col3, #T_1c9af_row7_col3, #T_1c9af_row8_col3, #T_1c9af_row9_col3, #T_1c9af_row10_col3, #T_1c9af_row11_col3, #T_1c9af_row12_col3, #T_1c9af_row13_col3, #T_1c9af_row14_col3, #T_1c9af_row15_col3, #T_1c9af_row16_col3, #T_1c9af_row17_col3, #T_1c9af_row18_col3, #T_1c9af_row19_col3, #T_1c9af_row20_col3, #T_1c9af_row21_col3, #T_1c9af_row22_col3, #T_1c9af_row23_col3, #T_1c9af_row24_col3, #T_1c9af_row25_col3, #T_1c9af_row26_col3, #T_1c9af_row27_col3, #T_1c9af_row28_col3, #T_1c9af_row29_col3, #T_1c9af_row30_col3, #T_1c9af_row31_col3, #T_1c9af_row32_col3, #T_1c9af_row33_col3, #T_1c9af_row34_col3, #T_1c9af_row35_col3, #T_1c9af_row36_col3, #T_1c9af_row37_col3, #T_1c9af_row38_col3, #T_1c9af_row39_col3, #T_1c9af_row40_col3, #T_1c9af_row41_col3, #T_1c9af_row42_col3, #T_1c9af_row43_col3, #T_1c9af_row44_col3, #T_1c9af_row45_col3, #T_1c9af_row46_col3, #T_1c9af_row47_col3, #T_1c9af_row48_col3, #T_1c9af_row49_col3, #T_1c9af_row50_col3, #T_1c9af_row51_col3, #T_1c9af_row52_col3, #T_1c9af_row53_col3, #T_1c9af_row54_col3, #T_1c9af_row55_col3, #T_1c9af_row56_col3, #T_1c9af_row57_col3, #T_1c9af_row58_col3, #T_1c9af_row59_col3, #T_1c9af_row60_col3, #T_1c9af_row61_col3, #T_1c9af_row62_col3, #T_1c9af_row63_col3, #T_1c9af_row64_col3, #T_1c9af_row65_col3, #T_1c9af_row66_col3, #T_1c9af_row67_col3, #T_1c9af_row68_col3, #T_1c9af_row69_col3, #T_1c9af_row70_col3, #T_1c9af_row71_col3, #T_1c9af_row72_col3, #T_1c9af_row73_col3, #T_1c9af_row74_col3, #T_1c9af_row75_col3, #T_1c9af_row76_col3 {
#   background-color: #fef70c;
# }
# #T_1c9af_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 90.0%, transparent 90.0%);
# }
# #T_1c9af_row1_col1, #T_1c9af_row172_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 15.8%, transparent 15.8%);
# }
# #T_1c9af_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.2%, red 15.2%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 11.6%, transparent 11.6%);
# }
# #T_1c9af_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.4%, red 3.4%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 36.0%, transparent 36.0%);
# }
# #T_1c9af_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 83.3%, transparent 83.3%);
# }
# #T_1c9af_row4_col1, #T_1c9af_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 17.8%, transparent 17.8%);
# }
# #T_1c9af_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.5%, red 18.5%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row5_col1, #T_1c9af_row52_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 37.0%, transparent 37.0%);
# }
# #T_1c9af_row5_col7, #T_1c9af_row204_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.5%, red 29.5%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row6_col1, #T_1c9af_row42_col1, #T_1c9af_row93_col1, #T_1c9af_row166_col1, #T_1c9af_row190_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 71.2%, transparent 71.2%);
# }
# #T_1c9af_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 44.5%, transparent 44.5%);
# }
# #T_1c9af_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 78.8%, transparent 78.8%);
# }
# #T_1c9af_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.2%, red 31.2%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row8_col1, #T_1c9af_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 93.2%, transparent 93.2%);
# }
# #T_1c9af_row8_col7, #T_1c9af_row191_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.6%, red 32.6%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 89.7%, transparent 89.7%);
# }
# #T_1c9af_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.0%, red 26.0%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row10_col1, #T_1c9af_row114_col1, #T_1c9af_row212_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 73.3%, transparent 73.3%);
# }
# #T_1c9af_row10_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 46.6%, transparent 46.6%);
# }
# #T_1c9af_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 39.0%, transparent 39.0%);
# }
# #T_1c9af_row11_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 95.7%, transparent 95.7%);
# }
# #T_1c9af_row12_col1, #T_1c9af_row13_col1, #T_1c9af_row219_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 8.2%, transparent 8.2%);
# }
# #T_1c9af_row12_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.1%, red 8.1%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row13_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 1.4%, red 1.4%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 36.6%, transparent 36.6%);
# }
# #T_1c9af_row14_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.2%, red 5.2%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row15_col1, #T_1c9af_row26_col1, #T_1c9af_row30_col1, #T_1c9af_row40_col1, #T_1c9af_row43_col1, #T_1c9af_row56_col1, #T_1c9af_row67_col1, #T_1c9af_row104_col1, #T_1c9af_row116_col1, #T_1c9af_row176_col1 {
#   width: 10em;
#   background-color: #fef70c;
# }
# #T_1c9af_row15_col7, #T_1c9af_row26_col7, #T_1c9af_row30_col7, #T_1c9af_row40_col7, #T_1c9af_row43_col7, #T_1c9af_row56_col7, #T_1c9af_row67_col7, #T_1c9af_row104_col7, #T_1c9af_row116_col7, #T_1c9af_row176_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row16_col1, #T_1c9af_row23_col1, #T_1c9af_row103_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 54.8%, transparent 54.8%);
# }
# #T_1c9af_row16_col6, #T_1c9af_row65_col2, #T_1c9af_row65_col5, #T_1c9af_row65_col8, #T_1c9af_row66_col5, #T_1c9af_row67_col5, #T_1c9af_row91_col4, #T_1c9af_row217_col3, #T_1c9af_row232_col0 {
#   background-color: green;
# }
# #T_1c9af_row16_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 100.0%, transparent 100.0%);
#   background-color: green;
# }
# #T_1c9af_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 66.4%, transparent 66.4%);
# }
# #T_1c9af_row17_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 11.9%, red 11.9%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row18_col1, #T_1c9af_row215_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 56.2%, transparent 56.2%);
# }
# #T_1c9af_row18_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.3%, red 13.3%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 59.6%, transparent 59.6%);
# }
# #T_1c9af_row19_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 80.0%, transparent 80.0%);
# }
# #T_1c9af_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 67.1%, transparent 67.1%);
# }
# #T_1c9af_row20_col7, #T_1c9af_row21_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.4%, red 23.4%, red 34.7%, transparent 34.7%);
# }
# #T_1c9af_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 78.1%, transparent 78.1%);
# }
# #T_1c9af_row22_col1, #T_1c9af_row46_col1, #T_1c9af_row117_col1, #T_1c9af_row163_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 79.5%, transparent 79.5%);
# }
# #T_1c9

# %% [markdown]
# ## 34.7 Heatmaps and Gradients
# ## 34.8 Captions

# %%
(agg_flow
 .reset_index()
 .style
 .format({'cost': '${:,.2f}', 'datetime': '{:%Y/%m}/01',
          'percent_quarterly_flow': '{:.1%}',
          'off_goal': '{:+.1%}',
          **{col: '{:.1f}' for col in ['cfs', 'total_flow', 'quarterly_flow']}},
         na_rep='Missing')
 .bar(subset='cfs', color='#c07fef', vmax=agg_flow.cfs.quantile(.95))
 .bar(subset='off_goal', color=['red','green'], align='mid')
 .highlight_null(null_color='#fef70c')
 .highlight_max(axis=0, color='green')
 .background_gradient(axis=0, cmap='Reds', subset='cost', vmin=1_000, vmax=25_000)
 .set_caption('Dirty Devil Summary')
 )
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_99193/65353877.py:11: FutureWarning: `null_color` is deprecated: use `color` instead
#   .highlight_null(null_color='#fef70c')
# <style type="text/css">
# #T_f9f42 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_f9f42 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_f9f42_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 32.2%, transparent 32.2%);
# }
# #T_f9f42_row0_col3, #T_f9f42_row1_col3, #T_f9f42_row2_col3, #T_f9f42_row3_col3, #T_f9f42_row4_col3, #T_f9f42_row5_col3, #T_f9f42_row6_col3, #T_f9f42_row7_col3, #T_f9f42_row8_col3, #T_f9f42_row9_col3, #T_f9f42_row10_col3, #T_f9f42_row11_col3, #T_f9f42_row12_col3, #T_f9f42_row13_col3, #T_f9f42_row14_col3, #T_f9f42_row15_col3, #T_f9f42_row16_col3, #T_f9f42_row17_col3, #T_f9f42_row18_col3, #T_f9f42_row19_col3, #T_f9f42_row20_col3, #T_f9f42_row21_col3, #T_f9f42_row22_col3, #T_f9f42_row23_col3, #T_f9f42_row24_col3, #T_f9f42_row25_col3, #T_f9f42_row26_col3, #T_f9f42_row27_col3, #T_f9f42_row28_col3, #T_f9f42_row29_col3, #T_f9f42_row30_col3, #T_f9f42_row31_col3, #T_f9f42_row32_col3, #T_f9f42_row33_col3, #T_f9f42_row34_col3, #T_f9f42_row35_col3, #T_f9f42_row36_col3, #T_f9f42_row37_col3, #T_f9f42_row38_col3, #T_f9f42_row39_col3, #T_f9f42_row40_col3, #T_f9f42_row41_col3, #T_f9f42_row42_col3, #T_f9f42_row43_col3, #T_f9f42_row44_col3, #T_f9f42_row45_col3, #T_f9f42_row46_col3, #T_f9f42_row47_col3, #T_f9f42_row48_col3, #T_f9f42_row49_col3, #T_f9f42_row50_col3, #T_f9f42_row51_col3, #T_f9f42_row52_col3, #T_f9f42_row53_col3, #T_f9f42_row54_col3, #T_f9f42_row55_col3, #T_f9f42_row56_col3, #T_f9f42_row57_col3, #T_f9f42_row58_col3, #T_f9f42_row59_col3, #T_f9f42_row60_col3, #T_f9f42_row61_col3, #T_f9f42_row62_col3, #T_f9f42_row63_col3, #T_f9f42_row64_col3, #T_f9f42_row65_col3, #T_f9f42_row66_col3, #T_f9f42_row67_col3, #T_f9f42_row68_col3, #T_f9f42_row69_col3, #T_f9f42_row70_col3, #T_f9f42_row71_col3, #T_f9f42_row72_col3, #T_f9f42_row73_col3, #T_f9f42_row74_col3, #T_f9f42_row75_col3, #T_f9f42_row76_col3 {
#   background-color: #fef70c;
# }
# #T_f9f42_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 90.0%, transparent 90.0%);
# }
# #T_f9f42_row0_col8 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_f9f42_row1_col1, #T_f9f42_row172_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 15.8%, transparent 15.8%);
# }
# #T_f9f42_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.2%, red 15.2%, red 34.7%, transparent 34.7%);
# }
# #T_f9f42_row1_col8 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_f9f42_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 11.6%, transparent 11.6%);
# }
# #T_f9f42_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.4%, red 3.4%, red 34.7%, transparent 34.7%);
# }
# #T_f9f42_row2_col8, #T_f9f42_row38_col8 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_f9f42_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 36.0%, transparent 36.0%);
# }
# #T_f9f42_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 83.3%, transparent 83.3%);
# }
# #T_f9f42_row3_col8, #T_f9f42_row5_col8, #T_f9f42_row6_col8, #T_f9f42_row7_col8, #T_f9f42_row8_col8, #T_f9f42_row9_col8, #T_f9f42_row10_col8, #T_f9f42_row11_col8, #T_f9f42_row16_col8, #T_f9f42_row19_col8, #T_f9f42_row20_col8, #T_f9f42_row21_col8, #T_f9f42_row22_col8, #T_f9f42_row23_col8, #T_f9f42_row29_col8, #T_f9f42_row32_col8, #T_f9f42_row33_col8, #T_f9f42_row34_col8, #T_f9f42_row44_col8, #T_f9f42_row47_col8, #T_f9f42_row48_col8, #T_f9f42_row49_col8, #T_f9f42_row52_col8, #T_f9f42_row53_col8, #T_f9f42_row57_col8, #T_f9f42_row58_col8, #T_f9f42_row59_col8, #T_f9f42_row66_col8, #T_f9f42_row69_col8, #T_f9f42_row70_col8, #T_f9f42_row71_col8, #T_f9f42_row74_col8, #T_f9f42_row76_col8, #T_f9f42_row78_col8, #T_f9f42_row79_col8, #T_f9f42_row80_col8, #T_f9f42_row81_col8, #T_f9f42_row82_col8, #T_f9f42_row83_col8, #T_f9f42_row84_col8, #T_f9f42_row87_col8, #T_f9f42_row90_col8, #T_f9f42_row91_col8, #T_f9f42_row93_col8, #T_f9f42_row94_col8, #T_f9f42_row95_col8, #T_f9f42_row96_col8, #T_f9f42_row97_col8, #T_f9f42_row102_col8, #T_f9f42_row106_col8, #T_f9f42_row109_col8, #T_f9f42_row111_col8, #T_f9f42_row113_col8, #T_f9f42_row114_col8, #T_f9f42_row115_col8, #T_f9f42_row118_col8, #T_f9f42_row119_col8, #T_f9f42_row120_col8, #T_f9f42_row121_col8, #T_f9f42_row122_col8, #T_f9f42_row123_col8, #T_f9f42_row124_col8, #T_f9f42_row125_col8, #T_f9f42_row126_col8, #T_f9f42_row129_col8, #T_f9f42_row130_col8, #T_f9f42_row131_col8, #T_f9f42_row134_col8, #T_f9f42_row135_col8, #T_f9f42_row136_col8, #T_f9f42_row137_col8, #T_f9f42_row138_col8, #T_f9f42_row139_col8, #T_f9f42_row141_col8, #T_f9f42_row142_col8, #T_f9f42_row143_col8, #T_f9f42_row147_col8, #T_f9f42_row148_col8, #T_f9f42_row149_col8, #T_f9f42_row150_col8, #T_f9f42_row153_col8, #T_f9f42_row154_col8, #T_f9f42_row160_col8, #T_f9f42_row161_col8, #T_f9f42_row162_col8, #T_f9f42_row163_col8, #T_f9f42_row164_col8, #T_f9f42_row165_col8, #T_f9f42_row166_col8, #T_f9f42_row167_col8, #T_f9f42_row168_col8, #T_f9f42_row169_col8, #T_f9f42_row170_col8, #T_f9f42_row171_col8, #T_f9f42_row172_col8, #T_f9f42_row173_col8, #T_f9f42_row174_col8, #T_f9f42_row177_col8, #T_f9f42_row178_col8, #T_f9f42_row179_col8, #T_f9f42_row180_col8, #T_f9f42_row184_col8, #T_f9f42_row185_col8, #T_f9f42_row186_col8, #T_f9f42_row187_col8, #T_f9f42_row188_col8, #T_f9f42_row189_col8, #T_f9f42_row190_col8, #T_f9f42_row191_col8, #T_f9f42_row192_col8, #T_f9f42_row193_col8, #T_f9f42_row194_col8, #T_f9f42_row196_col8, #T_f9f42_row197_col8, #T_f9f42_row198_col8, #T_f9f42_row199_col8, #T_f9f42_row200_col8, #T_f9f42_row201_col8, #T_f9f42_row202_col8, #T_f9f42_row203_col8, #T_f9f42_row209_col8, #T_f9f42_row210_col8, #T_f9f42_row211_col8, #T_f9f42_row212_col8, #T_f9f42_row213_col8, #T_f9f42_row214_col8, #T_f9f42_row215_col8, #T_f9f42_row216_col8, #T_f9f42_row217_col8, #T_f9f42_row218_col8, #T_f9f42_row222_col8, #T_f9f42_row223_col8, #T_f9f42_row224_col8, #T_f9f42_row225_col8, #T_f9f42_row226_col8, #T_f9f42_row227_col8 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f9f42_row4_col1, #T_f9f42_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 17.8%, transparent 17.8%);
# }
# #T_f9f42_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.5%, red 18.5%, red 34.7%, transparent 34.7%);
# }
# #T_f9f42_row4_col8 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_f9f42_row5_col1, #T_f9f42_row52_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 37.0%, transparent 37.0%);
# }
# #T_f9f42_row5_col7, #T_f9f42_row204_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.5%, red 29.5%, red 34.7%, transparent 34.7%);
# }
# #T_f9f42_row6_col1, #T_f9f42_row42_col1, #T_f9f42_row93_col1, #T_f9f42_row166_col1, #T_f9f42_row190_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 71.2%, transparent 71.2%);
# }
# #T_f9f42_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 44.5%, transparent 44.5%);
# }
# #T_f9f42_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 78.8%, transparent 78.8%);
# }
# #T_f9f42_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.2%, red 31.2%, red 34.7%, transparent 34.7%);
# }
# #T_f9f42_row8_col1, #T_f9f42_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 93.2%, transparent 93.2%);
# }
# #T_f9f42_row8_col7, #T_f9f42_row191_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.6%, red 32.6%, red 34.7%, transparent 34.7%);
# }
# #T_f9f42_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 89.7%, transparent 89.7%);
# }
# #T_f9f42_row9_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.0%, red 26.0%, red 34.7%, transparent 34.7%);
# }
# #T_f9f42_row10_col1, #T_f9f42_row114_col1, #T_f9f42_row212_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fe

# %% [markdown]
# ## 34.9 CSS Properties

# %%
(agg_flow
 .reset_index()
 .style
 .format({'cost': '${:,.2f}', 'datetime': '{:%Y/%m}/01',
          'percent_quarterly_flow': '{:.1%}',
          'off_goal': '{:+.1%}',
          **{col: '{:.1f}' for col in ['cfs', 'total_flow', 'quarterly_flow']}},
         na_rep='Missing')
 .bar(subset='cfs', color='#c07fef', vmax=agg_flow.cfs.quantile(.95))
 .bar(subset='off_goal', color=['red','green'], align='mid')
 .highlight_null(null_color='#fef70c')
 .highlight_max(axis=0, color='green')
 .background_gradient(axis=0, cmap='Reds', subset='cost', vmin=1_000, vmax=25_000)
 .set_caption('Dirty Devil Summary')
 .set_properties(**{'background-color': '#999'}, subset='datetime')
 .applymap(lambda val: f'color: "grey"; opacity: 80%; background-color:{"#4589ae" if val > 0 else "#c07fef"}',
           subset='cfs')
 .set_table_styles([{'selector': 'td:hover','props': 'background-color: pink; font-size:14pt;'}])
 )
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_99193/1811513687.py:11: FutureWarning: `null_color` is deprecated: use `color` instead
#   .highlight_null(null_color='#fef70c')
# <style type="text/css">
# #T_e9920 td:hover {
#   background-color: pink;
#   font-size: 14pt;
# }
# #T_e9920_row0_col0, #T_e9920_row1_col0, #T_e9920_row2_col0, #T_e9920_row3_col0, #T_e9920_row4_col0, #T_e9920_row5_col0, #T_e9920_row6_col0, #T_e9920_row7_col0, #T_e9920_row8_col0, #T_e9920_row9_col0, #T_e9920_row10_col0, #T_e9920_row11_col0, #T_e9920_row12_col0, #T_e9920_row13_col0, #T_e9920_row14_col0, #T_e9920_row15_col0, #T_e9920_row16_col0, #T_e9920_row17_col0, #T_e9920_row18_col0, #T_e9920_row19_col0, #T_e9920_row20_col0, #T_e9920_row21_col0, #T_e9920_row22_col0, #T_e9920_row23_col0, #T_e9920_row24_col0, #T_e9920_row25_col0, #T_e9920_row26_col0, #T_e9920_row27_col0, #T_e9920_row28_col0, #T_e9920_row29_col0, #T_e9920_row30_col0, #T_e9920_row31_col0, #T_e9920_row32_col0, #T_e9920_row33_col0, #T_e9920_row34_col0, #T_e9920_row35_col0, #T_e9920_row36_col0, #T_e9920_row37_col0, #T_e9920_row38_col0, #T_e9920_row39_col0, #T_e9920_row40_col0, #T_e9920_row41_col0, #T_e9920_row42_col0, #T_e9920_row43_col0, #T_e9920_row44_col0, #T_e9920_row45_col0, #T_e9920_row46_col0, #T_e9920_row47_col0, #T_e9920_row48_col0, #T_e9920_row49_col0, #T_e9920_row50_col0, #T_e9920_row51_col0, #T_e9920_row52_col0, #T_e9920_row53_col0, #T_e9920_row54_col0, #T_e9920_row55_col0, #T_e9920_row56_col0, #T_e9920_row57_col0, #T_e9920_row58_col0, #T_e9920_row59_col0, #T_e9920_row60_col0, #T_e9920_row61_col0, #T_e9920_row62_col0, #T_e9920_row63_col0, #T_e9920_row64_col0, #T_e9920_row65_col0, #T_e9920_row66_col0, #T_e9920_row67_col0, #T_e9920_row68_col0, #T_e9920_row69_col0, #T_e9920_row70_col0, #T_e9920_row71_col0, #T_e9920_row72_col0, #T_e9920_row73_col0, #T_e9920_row74_col0, #T_e9920_row75_col0, #T_e9920_row76_col0, #T_e9920_row77_col0, #T_e9920_row78_col0, #T_e9920_row79_col0, #T_e9920_row80_col0, #T_e9920_row81_col0, #T_e9920_row82_col0, #T_e9920_row83_col0, #T_e9920_row84_col0, #T_e9920_row85_col0, #T_e9920_row86_col0, #T_e9920_row87_col0, #T_e9920_row88_col0, #T_e9920_row89_col0, #T_e9920_row90_col0, #T_e9920_row91_col0, #T_e9920_row92_col0, #T_e9920_row93_col0, #T_e9920_row94_col0, #T_e9920_row95_col0, #T_e9920_row96_col0, #T_e9920_row97_col0, #T_e9920_row98_col0, #T_e9920_row99_col0, #T_e9920_row100_col0, #T_e9920_row101_col0, #T_e9920_row102_col0, #T_e9920_row103_col0, #T_e9920_row104_col0, #T_e9920_row105_col0, #T_e9920_row106_col0, #T_e9920_row107_col0, #T_e9920_row108_col0, #T_e9920_row109_col0, #T_e9920_row110_col0, #T_e9920_row111_col0, #T_e9920_row112_col0, #T_e9920_row113_col0, #T_e9920_row114_col0, #T_e9920_row115_col0, #T_e9920_row116_col0, #T_e9920_row117_col0, #T_e9920_row118_col0, #T_e9920_row119_col0, #T_e9920_row120_col0, #T_e9920_row121_col0, #T_e9920_row122_col0, #T_e9920_row123_col0, #T_e9920_row124_col0, #T_e9920_row125_col0, #T_e9920_row126_col0, #T_e9920_row127_col0, #T_e9920_row128_col0, #T_e9920_row129_col0, #T_e9920_row130_col0, #T_e9920_row131_col0, #T_e9920_row132_col0, #T_e9920_row133_col0, #T_e9920_row134_col0, #T_e9920_row135_col0, #T_e9920_row136_col0, #T_e9920_row137_col0, #T_e9920_row138_col0, #T_e9920_row139_col0, #T_e9920_row140_col0, #T_e9920_row141_col0, #T_e9920_row142_col0, #T_e9920_row143_col0, #T_e9920_row144_col0, #T_e9920_row145_col0, #T_e9920_row146_col0, #T_e9920_row147_col0, #T_e9920_row148_col0, #T_e9920_row149_col0, #T_e9920_row150_col0, #T_e9920_row151_col0, #T_e9920_row152_col0, #T_e9920_row153_col0, #T_e9920_row154_col0, #T_e9920_row155_col0, #T_e9920_row156_col0, #T_e9920_row157_col0, #T_e9920_row158_col0, #T_e9920_row159_col0, #T_e9920_row160_col0, #T_e9920_row161_col0, #T_e9920_row162_col0, #T_e9920_row163_col0, #T_e9920_row164_col0, #T_e9920_row165_col0, #T_e9920_row166_col0, #T_e9920_row167_col0, #T_e9920_row168_col0, #T_e9920_row169_col0, #T_e9920_row170_col0, #T_e9920_row171_col0, #T_e9920_row172_col0, #T_e9920_row173_col0, #T_e9920_row174_col0, #T_e9920_row175_col0, #T_e9920_row176_col0, #T_e9920_row177_col0, #T_e9920_row178_col0, #T_e9920_row179_col0, #T_e9920_row180_col0, #T_e9920_row181_col0, #T_e9920_row182_col0, #T_e9920_row183_col0, #T_e9920_row184_col0, #T_e9920_row185_col0, #T_e9920_row186_co ...
#   background-color: #999;
# }
# #T_e9920_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 32.2%, transparent 32.2%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_e9920_row0_col3, #T_e9920_row1_col3, #T_e9920_row2_col3, #T_e9920_row3_col3, #T_e9920_row4_col3, #T_e9920_row5_col3, #T_e9920_row6_col3, #T_e9920_row7_col3, #T_e9920_row8_col3, #T_e9920_row9_col3, #T_e9920_row10_col3, #T_e9920_row11_col3, #T_e9920_row12_col3, #T_e9920_row13_col3, #T_e9920_row14_col3, #T_e9920_row15_col3, #T_e9920_row16_col3, #T_e9920_row17_col3, #T_e9920_row18_col3, #T_e9920_row19_col3, #T_e9920_row20_col3, #T_e9920_row21_col3, #T_e9920_row22_col3, #T_e9920_row23_col3, #T_e9920_row24_col3, #T_e9920_row25_col3, #T_e9920_row26_col3, #T_e9920_row27_col3, #T_e9920_row28_col3, #T_e9920_row29_col3, #T_e9920_row30_col3, #T_e9920_row31_col3, #T_e9920_row32_col3, #T_e9920_row33_col3, #T_e9920_row34_col3, #T_e9920_row35_col3, #T_e9920_row36_col3, #T_e9920_row37_col3, #T_e9920_row38_col3, #T_e9920_row39_col3, #T_e9920_row40_col3, #T_e9920_row41_col3, #T_e9920_row42_col3, #T_e9920_row43_col3, #T_e9920_row44_col3, #T_e9920_row45_col3, #T_e9920_row46_col3, #T_e9920_row47_col3, #T_e9920_row48_col3, #T_e9920_row49_col3, #T_e9920_row50_col3, #T_e9920_row51_col3, #T_e9920_row52_col3, #T_e9920_row53_col3, #T_e9920_row54_col3, #T_e9920_row55_col3, #T_e9920_row56_col3, #T_e9920_row57_col3, #T_e9920_row58_col3, #T_e9920_row59_col3, #T_e9920_row60_col3, #T_e9920_row61_col3, #T_e9920_row62_col3, #T_e9920_row63_col3, #T_e9920_row64_col3, #T_e9920_row65_col3, #T_e9920_row66_col3, #T_e9920_row67_col3, #T_e9920_row68_col3, #T_e9920_row69_col3, #T_e9920_row70_col3, #T_e9920_row71_col3, #T_e9920_row72_col3, #T_e9920_row73_col3, #T_e9920_row74_col3, #T_e9920_row75_col3, #T_e9920_row76_col3 {
#   background-color: #fef70c;
# }
# #T_e9920_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 90.0%, transparent 90.0%);
# }
# #T_e9920_row0_col8 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_e9920_row1_col1, #T_e9920_row172_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 15.8%, transparent 15.8%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_e9920_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.2%, red 15.2%, red 34.7%, transparent 34.7%);
# }
# #T_e9920_row1_col8 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_e9920_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 11.6%, transparent 11.6%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_e9920_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.4%, red 3.4%, red 34.7%, transparent 34.7%);
# }
# #T_e9920_row2_col8, #T_e9920_row38_col8 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_e9920_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90

# %% [markdown]
# ## 34.10 Stickiness and Hiding

# %%
(agg_flow
 .reset_index()
 .style
 .format({'cost': '${:,.2f}', 'datetime': '{:%Y/%m}/01',
          'percent_quarterly_flow': '{:.1%}',
          'off_goal': '{:+.1%}',
          **{col: '{:.1f}' for col in ['cfs', 'total_flow', 'quarterly_flow']}},
         na_rep='Missing')
 .bar(subset='cfs', color='#c07fef', vmax=agg_flow.cfs.quantile(.95))
 .bar(subset='off_goal', color=['red','green'], align='mid')
 .highlight_null(null_color='#fef70c')
 .highlight_max(axis=0, color='green')
 .background_gradient(axis=0, cmap='Reds', subset='cost', vmin=1_000, vmax=25_000)
 .set_caption('Dirty Devil Summary')
 .set_properties(**{'background-color': '#999'}, subset='datetime')
 .applymap(lambda val: f'color: "grey"; opacity: 80%; background-color:{"#4589ae" if val > 0 else "#c07fef"}',
           subset='cfs')
 .set_table_styles([{'selector': 'td:hover','props': 'background-color: pink; font-size:14pt;'}])
 .set_sticky(axis='columns')
 )
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_99193/995953562.py:11: FutureWarning: `null_color` is deprecated: use `color` instead
#   .highlight_null(null_color='#fef70c')
# <style type="text/css">
# #T_29524 td:hover {
#   background-color: pink;
#   font-size: 14pt;
# }
# #T_29524 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_29524_row0_col0, #T_29524_row1_col0, #T_29524_row2_col0, #T_29524_row3_col0, #T_29524_row4_col0, #T_29524_row5_col0, #T_29524_row6_col0, #T_29524_row7_col0, #T_29524_row8_col0, #T_29524_row9_col0, #T_29524_row10_col0, #T_29524_row11_col0, #T_29524_row12_col0, #T_29524_row13_col0, #T_29524_row14_col0, #T_29524_row15_col0, #T_29524_row16_col0, #T_29524_row17_col0, #T_29524_row18_col0, #T_29524_row19_col0, #T_29524_row20_col0, #T_29524_row21_col0, #T_29524_row22_col0, #T_29524_row23_col0, #T_29524_row24_col0, #T_29524_row25_col0, #T_29524_row26_col0, #T_29524_row27_col0, #T_29524_row28_col0, #T_29524_row29_col0, #T_29524_row30_col0, #T_29524_row31_col0, #T_29524_row32_col0, #T_29524_row33_col0, #T_29524_row34_col0, #T_29524_row35_col0, #T_29524_row36_col0, #T_29524_row37_col0, #T_29524_row38_col0, #T_29524_row39_col0, #T_29524_row40_col0, #T_29524_row41_col0, #T_29524_row42_col0, #T_29524_row43_col0, #T_29524_row44_col0, #T_29524_row45_col0, #T_29524_row46_col0, #T_29524_row47_col0, #T_29524_row48_col0, #T_29524_row49_col0, #T_29524_row50_col0, #T_29524_row51_col0, #T_29524_row52_col0, #T_29524_row53_col0, #T_29524_row54_col0, #T_29524_row55_col0, #T_29524_row56_col0, #T_29524_row57_col0, #T_29524_row58_col0, #T_29524_row59_col0, #T_29524_row60_col0, #T_29524_row61_col0, #T_29524_row62_col0, #T_29524_row63_col0, #T_29524_row64_col0, #T_29524_row65_col0, #T_29524_row66_col0, #T_29524_row67_col0, #T_29524_row68_col0, #T_29524_row69_col0, #T_29524_row70_col0, #T_29524_row71_col0, #T_29524_row72_col0, #T_29524_row73_col0, #T_29524_row74_col0, #T_29524_row75_col0, #T_29524_row76_col0, #T_29524_row77_col0, #T_29524_row78_col0, #T_29524_row79_col0, #T_29524_row80_col0, #T_29524_row81_col0, #T_29524_row82_col0, #T_29524_row83_col0, #T_29524_row84_col0, #T_29524_row85_col0, #T_29524_row86_col0, #T_29524_row87_col0, #T_29524_row88_col0, #T_29524_row89_col0, #T_29524_row90_col0, #T_29524_row91_col0, #T_29524_row92_col0, #T_29524_row93_col0, #T_29524_row94_col0, #T_29524_row95_col0, #T_29524_row96_col0, #T_29524_row97_col0, #T_29524_row98_col0, #T_29524_row99_col0, #T_29524_row100_col0, #T_29524_row101_col0, #T_29524_row102_col0, #T_29524_row103_col0, #T_29524_row104_col0, #T_29524_row105_col0, #T_29524_row106_col0, #T_29524_row107_col0, #T_29524_row108_col0, #T_29524_row109_col0, #T_29524_row110_col0, #T_29524_row111_col0, #T_29524_row112_col0, #T_29524_row113_col0, #T_29524_row114_col0, #T_29524_row115_col0, #T_29524_row116_col0, #T_29524_row117_col0, #T_29524_row118_col0, #T_29524_row119_col0, #T_29524_row120_col0, #T_29524_row121_col0, #T_29524_row122_col0, #T_29524_row123_col0, #T_29524_row124_col0, #T_29524_row125_col0, #T_29524_row126_col0, #T_29524_row127_col0, #T_29524_row128_col0, #T_29524_row129_col0, #T_29524_row130_col0, #T_29524_row131_col0, #T_29524_row132_col0, #T_29524_row133_col0, #T_29524_row134_col0, #T_29524_row135_col0, #T_29524_row136_col0, #T_29524_row137_col0, #T_29524_row138_col0, #T_29524_row139_col0, #T_29524_row140_col0, #T_29524_row141_col0, #T_29524_row142_col0, #T_29524_row143_col0, #T_29524_row144_col0, #T_29524_row145_col0, #T_29524_row146_col0, #T_29524_row147_col0, #T_29524_row148_col0, #T_29524_row149_col0, #T_29524_row150_col0, #T_29524_row151_col0, #T_29524_row152_col0, #T_29524_row153_col0, #T_29524_row154_col0, #T_29524_row155_col0, #T_29524_row156_col0, #T_29524_row157_col0, #T_29524_row158_col0, #T_29524_row159_col0, #T_29524_row160_col0, #T_29524_row161_col0, #T_29524_row162_col0, #T_29524_row163_col0, #T_29524_row164_col0, #T_29524_row165_col0, #T_29524_row166_col0, #T_29524_row167_col0, #T_29524_row168_col0, #T_29524_row169_col0, #T_29524_row170_col0, #T_29524_row171_col0, #T_29524_row172_col0, #T_29524_row173_col0, #T_29524_row174_col0, #T_29524_row175_col0, #T_29524_row176_col0, #T_29524_row177_col0, #T_29524_row178_col0, #T_29524_row179_col0, #T_29524_row180_col0, #T_29524_row181_col0, #T_29524_row182_col0, #T_29524_row183_col0, #T_29524_row184_col0, #T_29524_row185_col0, #T_29524_row186_co ...
#   background-color: #999;
# }
# #T_29524_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 32.2%, transparent 32.2%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_29524_row0_col3, #T_29524_row1_col3, #T_29524_row2_col3, #T_29524_row3_col3, #T_29524_row4_col3, #T_29524_row5_col3, #T_29524_row6_col3, #T_29524_row7_col3, #T_29524_row8_col3, #T_29524_row9_col3, #T_29524_row10_col3, #T_29524_row11_col3, #T_29524_row12_col3, #T_29524_row13_col3, #T_29524_row14_col3, #T_29524_row15_col3, #T_29524_row16_col3, #T_29524_row17_col3, #T_29524_row18_col3, #T_29524_row19_col3, #T_29524_row20_col3, #T_29524_row21_col3, #T_29524_row22_col3, #T_29524_row23_col3, #T_29524_row24_col3, #T_29524_row25_col3, #T_29524_row26_col3, #T_29524_row27_col3, #T_29524_row28_col3, #T_29524_row29_col3, #T_29524_row30_col3, #T_29524_row31_col3, #T_29524_row32_col3, #T_29524_row33_col3, #T_29524_row34_col3, #T_29524_row35_col3, #T_29524_row36_col3, #T_29524_row37_col3, #T_29524_row38_col3, #T_29524_row39_col3, #T_29524_row40_col3, #T_29524_row41_col3, #T_29524_row42_col3, #T_29524_row43_col3, #T_29524_row44_col3, #T_29524_row45_col3, #T_29524_row46_col3, #T_29524_row47_col3, #T_29524_row48_col3, #T_29524_row49_col3, #T_29524_row50_col3, #T_29524_row51_col3, #T_29524_row52_col3, #T_29524_row53_col3, #T_29524_row54_col3, #T_29524_row55_col3, #T_29524_row56_col3, #T_29524_row57_col3, #T_29524_row58_col3, #T_29524_row59_col3, #T_29524_row60_col3, #T_29524_row61_col3, #T_29524_row62_col3, #T_29524_row63_col3, #T_29524_row64_col3, #T_29524_row65_col3, #T_29524_row66_col3, #T_29524_row67_col3, #T_29524_row68_col3, #T_29524_row69_col3, #T_29524_row70_col3, #T_29524_row71_col3, #T_29524_row72_col3, #T_29524_row73_col3, #T_29524_row74_col3, #T_29524_row75_col3, #T_29524_row76_col3 {
#   background-color: #fef70c;
# }
# #T_29524_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 90.0%, transparent 90.0%);
# }
# #T_29524_row0_col8 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_29524_row1_col1, #T_29524_row172_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 15.8%, transparent 15.8%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_29524_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.2%, red 15.2%, red 34.7%, transparent 34.7%);
# }
# #T_29524_row1_col8 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_29524_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 11.6%, transparent 11.6%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_29524_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.4%, red 3.4%, red 34.7%, transparent 34.7%);
# }
# #T_29524_row2_col8, #T_29524_row38_col8 {
#   ba

# %% [markdown]
# ## 34.11 Hiding the Index

# %%
(agg_flow
 .reset_index()
 .style
 .format({'cost': '${:,.2f}', 'datetime': '{:%Y/%m}/01',
          'percent_quarterly_flow': '{:.1%}',
          'off_goal': '{:+.1%}',
          **{col: '{:.1f}' for col in ['cfs', 'total_flow', 'quarterly_flow']}},
         na_rep='Missing')
 .bar(subset='cfs', color='#c07fef', vmax=agg_flow.cfs.quantile(.95))
 .bar(subset='off_goal', color=['red','green'], align='mid')
 .highlight_null(null_color='#fef70c')
 .highlight_max(axis=0, color='green')
 .background_gradient(axis=0, cmap='Reds', subset='cost', vmin=1_000, vmax=25_000)
 .set_caption('Dirty Devil Summary')
 .set_properties(**{'background-color': '#999'}, subset='datetime')
 .applymap(lambda val: f'color: "grey"; opacity: 80%; background-color:{"#4589ae" if val > 0 else "#c07fef"}',
           subset='cfs')
 .set_table_styles([{'selector': 'td:hover','props': 'background-color: pink; font-size:14pt;'}])
 .set_sticky(axis='columns')
 .hide_index()
 )
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_99193/3316754861.py:11: FutureWarning: `null_color` is deprecated: use `color` instead
#   .highlight_null(null_color='#fef70c')
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_99193/3316754861.py:20: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   .hide_index()
# <style type="text/css">
# #T_4e6f0 td:hover {
#   background-color: pink;
#   font-size: 14pt;
# }
# #T_4e6f0 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_4e6f0_row0_col0, #T_4e6f0_row1_col0, #T_4e6f0_row2_col0, #T_4e6f0_row3_col0, #T_4e6f0_row4_col0, #T_4e6f0_row5_col0, #T_4e6f0_row6_col0, #T_4e6f0_row7_col0, #T_4e6f0_row8_col0, #T_4e6f0_row9_col0, #T_4e6f0_row10_col0, #T_4e6f0_row11_col0, #T_4e6f0_row12_col0, #T_4e6f0_row13_col0, #T_4e6f0_row14_col0, #T_4e6f0_row15_col0, #T_4e6f0_row16_col0, #T_4e6f0_row17_col0, #T_4e6f0_row18_col0, #T_4e6f0_row19_col0, #T_4e6f0_row20_col0, #T_4e6f0_row21_col0, #T_4e6f0_row22_col0, #T_4e6f0_row23_col0, #T_4e6f0_row24_col0, #T_4e6f0_row25_col0, #T_4e6f0_row26_col0, #T_4e6f0_row27_col0, #T_4e6f0_row28_col0, #T_4e6f0_row29_col0, #T_4e6f0_row30_col0, #T_4e6f0_row31_col0, #T_4e6f0_row32_col0, #T_4e6f0_row33_col0, #T_4e6f0_row34_col0, #T_4e6f0_row35_col0, #T_4e6f0_row36_col0, #T_4e6f0_row37_col0, #T_4e6f0_row38_col0, #T_4e6f0_row39_col0, #T_4e6f0_row40_col0, #T_4e6f0_row41_col0, #T_4e6f0_row42_col0, #T_4e6f0_row43_col0, #T_4e6f0_row44_col0, #T_4e6f0_row45_col0, #T_4e6f0_row46_col0, #T_4e6f0_row47_col0, #T_4e6f0_row48_col0, #T_4e6f0_row49_col0, #T_4e6f0_row50_col0, #T_4e6f0_row51_col0, #T_4e6f0_row52_col0, #T_4e6f0_row53_col0, #T_4e6f0_row54_col0, #T_4e6f0_row55_col0, #T_4e6f0_row56_col0, #T_4e6f0_row57_col0, #T_4e6f0_row58_col0, #T_4e6f0_row59_col0, #T_4e6f0_row60_col0, #T_4e6f0_row61_col0, #T_4e6f0_row62_col0, #T_4e6f0_row63_col0, #T_4e6f0_row64_col0, #T_4e6f0_row65_col0, #T_4e6f0_row66_col0, #T_4e6f0_row67_col0, #T_4e6f0_row68_col0, #T_4e6f0_row69_col0, #T_4e6f0_row70_col0, #T_4e6f0_row71_col0, #T_4e6f0_row72_col0, #T_4e6f0_row73_col0, #T_4e6f0_row74_col0, #T_4e6f0_row75_col0, #T_4e6f0_row76_col0, #T_4e6f0_row77_col0, #T_4e6f0_row78_col0, #T_4e6f0_row79_col0, #T_4e6f0_row80_col0, #T_4e6f0_row81_col0, #T_4e6f0_row82_col0, #T_4e6f0_row83_col0, #T_4e6f0_row84_col0, #T_4e6f0_row85_col0, #T_4e6f0_row86_col0, #T_4e6f0_row87_col0, #T_4e6f0_row88_col0, #T_4e6f0_row89_col0, #T_4e6f0_row90_col0, #T_4e6f0_row91_col0, #T_4e6f0_row92_col0, #T_4e6f0_row93_col0, #T_4e6f0_row94_col0, #T_4e6f0_row95_col0, #T_4e6f0_row96_col0, #T_4e6f0_row97_col0, #T_4e6f0_row98_col0, #T_4e6f0_row99_col0, #T_4e6f0_row100_col0, #T_4e6f0_row101_col0, #T_4e6f0_row102_col0, #T_4e6f0_row103_col0, #T_4e6f0_row104_col0, #T_4e6f0_row105_col0, #T_4e6f0_row106_col0, #T_4e6f0_row107_col0, #T_4e6f0_row108_col0, #T_4e6f0_row109_col0, #T_4e6f0_row110_col0, #T_4e6f0_row111_col0, #T_4e6f0_row112_col0, #T_4e6f0_row113_col0, #T_4e6f0_row114_col0, #T_4e6f0_row115_col0, #T_4e6f0_row116_col0, #T_4e6f0_row117_col0, #T_4e6f0_row118_col0, #T_4e6f0_row119_col0, #T_4e6f0_row120_col0, #T_4e6f0_row121_col0, #T_4e6f0_row122_col0, #T_4e6f0_row123_col0, #T_4e6f0_row124_col0, #T_4e6f0_row125_col0, #T_4e6f0_row126_col0, #T_4e6f0_row127_col0, #T_4e6f0_row128_col0, #T_4e6f0_row129_col0, #T_4e6f0_row130_col0, #T_4e6f0_row131_col0, #T_4e6f0_row132_col0, #T_4e6f0_row133_col0, #T_4e6f0_row134_col0, #T_4e6f0_row135_col0, #T_4e6f0_row136_col0, #T_4e6f0_row137_col0, #T_4e6f0_row138_col0, #T_4e6f0_row139_col0, #T_4e6f0_row140_col0, #T_4e6f0_row141_col0, #T_4e6f0_row142_col0, #T_4e6f0_row143_col0, #T_4e6f0_row144_col0, #T_4e6f0_row145_col0, #T_4e6f0_row146_col0, #T_4e6f0_row147_col0, #T_4e6f0_row148_col0, #T_4e6f0_row149_col0, #T_4e6f0_row150_col0, #T_4e6f0_row151_col0, #T_4e6f0_row152_col0, #T_4e6f0_row153_col0, #T_4e6f0_row154_col0, #T_4e6f0_row155_col0, #T_4e6f0_row156_col0, #T_4e6f0_row157_col0, #T_4e6f0_row158_col0, #T_4e6f0_row159_col0, #T_4e6f0_row160_col0, #T_4e6f0_row161_col0, #T_4e6f0_row162_col0, #T_4e6f0_row163_col0, #T_4e6f0_row164_col0, #T_4e6f0_row165_col0, #T_4e6f0_row166_col0, #T_4e6f0_row167_col0, #T_4e6f0_row168_col0, #T_4e6f0_row169_col0, #T_4e6f0_row170_col0, #T_4e6f0_row171_col0, #T_4e6f0_row172_col0, #T_4e6f0_row173_col0, #T_4e6f0_row174_col0, #T_4e6f0_row175_col0, #T_4e6f0_row176_col0, #T_4e6f0_row177_col0, #T_4e6f0_row178_col0, #T_4e6f0_row179_col0, #T_4e6f0_row180_col0, #T_4e6f0_row181_col0, #T_4e6f0_row182_col0, #T_4e6f0_row183_col0, #T_4e6f0_row184_col0, #T_4e6f0_row185_col0, #T_4e6f0_row186_co ...
#   background-color: #999;
# }
# #T_4e6f0_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 32.2%, transparent 32.2%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_4e6f0_row0_col3, #T_4e6f0_row1_col3, #T_4e6f0_row2_col3, #T_4e6f0_row3_col3, #T_4e6f0_row4_col3, #T_4e6f0_row5_col3, #T_4e6f0_row6_col3, #T_4e6f0_row7_col3, #T_4e6f0_row8_col3, #T_4e6f0_row9_col3, #T_4e6f0_row10_col3, #T_4e6f0_row11_col3, #T_4e6f0_row12_col3, #T_4e6f0_row13_col3, #T_4e6f0_row14_col3, #T_4e6f0_row15_col3, #T_4e6f0_row16_col3, #T_4e6f0_row17_col3, #T_4e6f0_row18_col3, #T_4e6f0_row19_col3, #T_4e6f0_row20_col3, #T_4e6f0_row21_col3, #T_4e6f0_row22_col3, #T_4e6f0_row23_col3, #T_4e6f0_row24_col3, #T_4e6f0_row25_col3, #T_4e6f0_row26_col3, #T_4e6f0_row27_col3, #T_4e6f0_row28_col3, #T_4e6f0_row29_col3, #T_4e6f0_row30_col3, #T_4e6f0_row31_col3, #T_4e6f0_row32_col3, #T_4e6f0_row33_col3, #T_4e6f0_row34_col3, #T_4e6f0_row35_col3, #T_4e6f0_row36_col3, #T_4e6f0_row37_col3, #T_4e6f0_row38_col3, #T_4e6f0_row39_col3, #T_4e6f0_row40_col3, #T_4e6f0_row41_col3, #T_4e6f0_row42_col3, #T_4e6f0_row43_col3, #T_4e6f0_row44_col3, #T_4e6f0_row45_col3, #T_4e6f0_row46_col3, #T_4e6f0_row47_col3, #T_4e6f0_row48_col3, #T_4e6f0_row49_col3, #T_4e6f0_row50_col3, #T_4e6f0_row51_col3, #T_4e6f0_row52_col3, #T_4e6f0_row53_col3, #T_4e6f0_row54_col3, #T_4e6f0_row55_col3, #T_4e6f0_row56_col3, #T_4e6f0_row57_col3, #T_4e6f0_row58_col3, #T_4e6f0_row59_col3, #T_4e6f0_row60_col3, #T_4e6f0_row61_col3, #T_4e6f0_row62_col3, #T_4e6f0_row63_col3, #T_4e6f0_row64_col3, #T_4e6f0_row65_col3, #T_4e6f0_row66_col3, #T_4e6f0_row67_col3, #T_4e6f0_row68_col3, #T_4e6f0_row69_col3, #T_4e6f0_row70_col3, #T_4e6f0_row71_col3, #T_4e6f0_row72_col3, #T_4e6f0_row73_col3, #T_4e6f0_row74_col3, #T_4e6f0_row75_col3, #T_4e6f0_row76_col3 {
#   background-color: #fef70c;
# }
# #T_4e6f0_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 90.0%, transparent 90.0%);
# }
# #T_4e6f0_row0_col8 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_4e6f0_row1_col1, #T_4e6f0_row172_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 15.8%, transparent 15.8%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_4e6f0_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.2%, red 15.2%, red 34.7%, transparent 34.7%);
# }
# #T_4e6f0_row1_col8 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_4e6f0_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #c07fef 11.6%, transparent 11.6%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_4e6f0_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.4%, red 3.4%, red 34.7%, transparent 34.7%);
# }
# #T_4e6f0_row2_col8, #T_4e6f0_row38_col8 {
#   ba
