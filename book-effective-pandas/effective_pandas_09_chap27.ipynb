# %% [markdown]
# # Chapter 27

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %%
jb2 = pd.read_csv('data/jet_brains_python_2020_survey_data_cleaned.csv', index_col=0)
jb2
# Out:
#        age are_you_datascientist  company_size        country_live  \
# 1       21                  True          5000               India
# 2       30                 False          5000       United States
# 10      21                 False            51       Other country
# 11      21                  True            51       United States
# 13      30                  True          5000             Belgium
# ...    ...                   ...           ...                 ...
# 54456   30                 False          1001              Turkey
# 54457   21                 False             2  Russian Federation
# 54459   21                 False             1  Russian Federation
# 54460   30                  True            51               Spain
# 54461   21                 False            11             Algeria
#
#                                        employment_status  \
# 1             Fully employed by a company / organization
# 2             Fully employed by a company / organization
# 10            Fully employed by a company / organization
# 11            Fully employed by a company / organization
# 13            Fully employed by a company / organization
# ...                                                  ...
# 54456         Fully employed by a company / organization
# 54457         Fully employed by a company / organization
# 54459  Self-employed (a person earning income directl...
# 54460         Fully employed by a company / organization
# 54461         Fully employed by a company / organization
#
#                       first_learn_about_main_ide how_often_use_main_ide  \
# 1                            School / University                  Daily
# 2                             Friend / Colleague                  Daily
# 10                           School / University                  Daily
# 11      Online learning platform / Online course                  Daily
# 13                                Social network                  Daily
# ...                                          ...                    ...
# 54456                         Friend / Colleague                  Daily
# 54457                        School / University                  Daily
# 54459                         Friend / Colleague                  Daily
# 54460                             Search engines                  Daily
# 54461   Online learning platform / Online course                  Daily
#
#                            ide_main is_python_main  \
# 1                           VS Code            Yes
# 2                               Vim            Yes
# 10                    IntelliJ IDEA            Yes
# 11        PyCharm Community Edition            Yes
# 13                          VS Code            Yes
# ...                             ...            ...
# 54456     PyCharm Community Edition            Yes
# 54457                           Vim            Yes
# 54459  PyCharm Professional Edition            Yes
# 54460                         Other            Yes
# 54461                       VS Code            Yes
#
#                                         job_team               main_purposes  \
# 1                                 Work in a team  Both for work and personal
# 2      Work on your own project(s) independently  Both for work and personal
# 10                                Work in a team  Both for work and personal
# 11                                Work in a team  Both for work and personal
# 13                                Work in a team  Both for work and personal
# ...                                          ...                         ...
# 54456  Work on your own project(s) independently  Both for work and personal
# 54457  Work on your own project(s) independently  Both for work and personal
# 54459                             Work in a team  Both for work and personal
# 54460  Work on your own project(s) independently  Both for work and personal
# 54461                             Work in a team  Both for work and personal
#
#                 missing_features_main_ide  nps_main_ide  python_years  \
# 1      No, it has all the features I need           8.0           3.0
# 2      No, it has all the features I need          10.0           3.0
# 10     No, it has all the features I need          10.0           1.0
# 11     No, it has all the features I need           9.0           3.0
# 13     No, it has all the features I need          10.0           6.0
# ...                                   ...           ...           ...
# 54456  No, it has all the features I need           9.0           1.0
# 54457  No, it has all the features I need          10.0           6.0
# 54459  No, it has all the features I need          10.0           3.0
# 54460                  Yes – Please list:           3.0           6.0
# 54461  No, it has all the features I need          10.0           1.0
#
#       python3_version_most                                   several_projects  \
# 1               Python 3_6  Yes, I work on one main and several side projects
# 2               Python 3_6  Yes, I work on one main and several side projects
# 10              Python 3_8  Yes, I work on one main and several side projects
# 11              Python 3_9             Yes, I work on many different projects
# 13              Python 3_7             Yes, I work on many different projects
# ...                    ...                                                ...
# 54456           Python 3_6             Yes, I work on many different projects
# 54457           Python 3_6             Yes, I work on many different projects
# 54459           Python 3_7             Yes, I work on many different projects
# 54460           Python 3_7             Yes, I work on many different projects
# 54461           Python 3_8             Yes, I work on many different projects
#
#        team_size                                    use_python_most  \
# 1              2                               Software prototyping
# 2              4  DevOps / System administration / Writing autom...
# 10             2                                    Web development
# 11             2                                      Data analysis
# 13             2                                      Data analysis
# ...          ...                                                ...
# 54456          5                                   Machine learning
# 54457          2                                      Data analysis
# 54459          1                                    Web development
# 54460          4                                      Data analysis
# 54461          2                                            Unknown
#
#        years_of_coding  python3_ver
# 1                  3.0          3.6
# 2                  3.0          3.6
# 10                 1.0          3.8
# 11                 3.0          3.9
# 13                 3.0          3.7
# ...                ...          ...
# 54456              6.0          3.6
# 54457              1.0          3.6
# 54459              6.0          3.7
# 54460              3.0          3.7
# 54461              1.0          3.8
#
# [13711 rows x 20 columns]

# %%
(jb2
    .pivot_table(index='country_live', columns='employment_status',
                values='age', aggfunc='mean')
)
# Out:
# employment_status  Fully employed by a company / organization  \
# country_live
# Algeria                                             31.200000
# Argentina                                           30.632184
# Armenia                                             22.071429
# Australia                                           32.935622
# Austria                                             31.619565
# ...                                                       ...
# United States                                       32.429163
# Uruguay                                             27.000000
# Uzbekistan                                          21.000000
# Venezuela                                           29.769231
# Viet Nam                                            22.857143
#
# employment_status  Partially employed by a company / organization  \
# country_live
# Algeria                                                 24.000000
# Argentina                                               30.333333
# Armenia                                                       NaN
# Australia                                               28.000000
# Austria                                                 30.357143
# ...                                                           ...
# United States                                           27.500000
# Uruguay                                                 30.250000
# Uzbekistan                                              21.000000
# Venezuela                                               30.666667
# Viet Nam                                                      NaN
#
# employment_status  Self-employed (a person earning income directly from one's own business, trade, or profession)  \
# country_live
# Algeria                                                    27.000000
# Argentina                                                  28.300000
# Armenia                                                    24.000000
# Australia                                                  42.360000
# Austria                                                    35.000000
# ...                                                              ...
# United States                                              39.324324
# Uruguay                                                    30.000000
# Uzbekistan                                                       NaN
# Venezuela                                                  27.800000
# Viet Nam                                                   34.000000
#
# employment_status  Working student
# country_live
# Algeria                        NaN
# Argentina                23.000000
# Armenia                        NaN
# Australia                24.125000
# Austria                  25.500000
# ...                            ...
# United States            21.842697
# Uruguay                        NaN
# Uzbekistan                     NaN
# Venezuela                30.000000
# Viet Nam                 21.000000
#
# [76 rows x 4 columns]

# %%
pd.crosstab(index=jb2.country_live, columns=jb2.employment_status,
            values=jb2.age, aggfunc='mean')
# Out:
# employment_status  Fully employed by a company / organization  \
# country_live
# Algeria                                             31.200000
# Argentina                                           30.632184
# Armenia                                             22.071429
# Australia                                           32.935622
# Austria                                             31.619565
# ...                                                       ...
# United States                                       32.429163
# Uruguay                                             27.000000
# Uzbekistan                                          21.000000
# Venezuela                                           29.769231
# Viet Nam                                            22.857143
#
# employment_status  Partially employed by a company / organization  \
# country_live
# Algeria                                                 24.000000
# Argentina                                               30.333333
# Armenia                                                       NaN
# Australia                                               28.000000
# Austria                                                 30.357143
# ...                                                           ...
# United States                                           27.500000
# Uruguay                                                 30.250000
# Uzbekistan                                              21.000000
# Venezuela                                               30.666667
# Viet Nam                                                      NaN
#
# employment_status  Self-employed (a person earning income directly from one's own business, trade, or profession)  \
# country_live
# Algeria                                                    27.000000
# Argentina                                                  28.300000
# Armenia                                                    24.000000
# Australia                                                  42.360000
# Austria                                                    35.000000
# ...                                                              ...
# United States                                              39.324324
# Uruguay                                                    30.000000
# Uzbekistan                                                       NaN
# Venezuela                                                  27.800000
# Viet Nam                                                   34.000000
#
# employment_status  Working student
# country_live
# Algeria                        NaN
# Argentina                23.000000
# Armenia                        NaN
# Australia                24.125000
# Austria                  25.500000
# ...                            ...
# United States            21.842697
# Uruguay                        NaN
# Uzbekistan                     NaN
# Venezuela                30.000000
# Viet Nam                 21.000000
#
# [76 rows x 4 columns]

# %%
(jb2
 .groupby(['country_live', 'employment_status'])
 .age 
 .mean()
 .unstack()
)
# Out:
# employment_status  Fully employed by a company / organization  \
# country_live
# Algeria                                             31.200000
# Argentina                                           30.632184
# Armenia                                             22.071429
# Australia                                           32.935622
# Austria                                             31.619565
# ...                                                       ...
# United States                                       32.429163
# Uruguay                                             27.000000
# Uzbekistan                                          21.000000
# Venezuela                                           29.769231
# Viet Nam                                            22.857143
#
# employment_status  Partially employed by a company / organization  \
# country_live
# Algeria                                                 24.000000
# Argentina                                               30.333333
# Armenia                                                       NaN
# Australia                                               28.000000
# Austria                                                 30.357143
# ...                                                           ...
# United States                                           27.500000
# Uruguay                                                 30.250000
# Uzbekistan                                              21.000000
# Venezuela                                               30.666667
# Viet Nam                                                      NaN
#
# employment_status  Self-employed (a person earning income directly from one's own business, trade, or profession)  \
# country_live
# Algeria                                                    27.000000
# Argentina                                                  28.300000
# Armenia                                                    24.000000
# Australia                                                  42.360000
# Austria                                                    35.000000
# ...                                                              ...
# United States                                              39.324324
# Uruguay                                                    30.000000
# Uzbekistan                                                       NaN
# Venezuela                                                  27.800000
# Viet Nam                                                   34.000000
#
# employment_status  Working student
# country_live
# Algeria                        NaN
# Argentina                23.000000
# Armenia                        NaN
# Australia                24.125000
# Austria                  25.500000
# ...                            ...
# United States            21.842697
# Uruguay                        NaN
# Uzbekistan                     NaN
# Venezuela                30.000000
# Viet Nam                 21.000000
#
# [76 rows x 4 columns]

# %% [markdown]
# ## Using a Custom Aggregation Function

# %%
def per_emacs(ser):
    return ser.str.contains('Emacs').sum() / len(ser) * 100

# %%
(jb2
 .pivot_table(index='country_live', values='ide_main',
              aggfunc=per_emacs))
# Out:
#                ide_main
# country_live
# Algeria        0.000000
# Argentina      3.669725
# Armenia        0.000000
# Australia      3.649635
# Austria        1.562500
# ...                 ...
# United States  4.486466
# Uruguay        0.000000
# Uzbekistan     0.000000
# Venezuela      0.000000
# Viet Nam       0.000000
#
# [76 rows x 1 columns]

# %%
pd.crosstab(index=jb2.country_live,
            columns=jb2.assign(iden='emacs_per').iden,
            values=jb2.ide_main, aggfunc=per_emacs)
# Out:
# iden           emacs_per
# country_live
# Algeria         0.000000
# Argentina       3.669725
# Armenia         0.000000
# Australia       3.649635
# Austria         1.562500
# ...                  ...
# United States   4.486466
# Uruguay         0.000000
# Uzbekistan      0.000000
# Venezuela       0.000000
# Viet Nam        0.000000
#
# [76 rows x 1 columns]

# %%
(jb2
 .groupby('country_live')
 [['ide_main']]
 .agg(per_emacs)
)
# Out:
#                ide_main
# country_live
# Algeria        0.000000
# Argentina      3.669725
# Armenia        0.000000
# Australia      3.649635
# Austria        1.562500
# ...                 ...
# United States  4.486466
# Uruguay        0.000000
# Uzbekistan     0.000000
# Venezuela      0.000000
# Viet Nam       0.000000
#
# [76 rows x 1 columns]

# %% [markdown]
# ## 27.3 Multiple Aggregations

# %%
(jb2
 .pivot_table(index='country_live', values='age',
              aggfunc=(min, max)))
# Out:
#                max  min
# country_live
# Algeria         60   18
# Argentina       60   18
# Armenia         30   18
# Australia       60   18
# Austria         50   18
# ...            ...  ...
# United States   60   18
# Uruguay         40   21
# Uzbekistan      21   21
# Venezuela       50   18
# Viet Nam        60   18
#
# [76 rows x 2 columns]

# %%
(jb2
 .groupby('country_live')
 .age
 .agg([min, max])) #['min'].value_counts()
# Out:
#                min  max
# country_live
# Algeria         18   60
# Argentina       18   60
# Armenia         18   30
# Australia       18   60
# Austria         18   50
# ...            ...  ...
# United States   18   60
# Uruguay         21   40
# Uzbekistan      21   21
# Venezuela       18   50
# Viet Nam        18   60
#
# [76 rows x 2 columns]

# %%
pd.crosstab(jb2.country_live, values=jb2.age, aggfunc=(min, max),
            columns=jb2.assign(val='age').val)
# Out:
#               max min
# val           age age
# country_live
# Algeria        60  18
# Argentina      60  18
# Armenia        30  18
# Australia      60  18
# Austria        50  18
# ...            ..  ..
# United States  60  18
# Uruguay        40  21
# Uzbekistan     21  21
# Venezuela      50  18
# Viet Nam       60  18
#
# [76 rows x 2 columns]

# %% [markdown]
# ## 27.4 Per Column Aggregations

# %%
(jb2
 .pivot_table(index='country_live',
              aggfunc=(min, max)))
# Out:
#               age     are_you_datascientist        company_size      \
#               max min                   max    min          max min
# country_live
# Algeria        60  18                  True  False         5000   1
# Argentina      60  18                  True  False         5000   1
# Armenia        30  18                  True  False         5000   1
# Australia      60  18                  True  False         5000   1
# Austria        50  18                  True  False         5000   1
# ...            ..  ..                   ...    ...          ...  ..
# United States  60  18                  True  False         5000   1
# Uruguay        40  21                  True  False         5000   2
# Uzbekistan     21  21                  True  False         5000   1
# Venezuela      50  18                  True  False         5000   1
# Viet Nam       60  18                  True  False         5000   1
#
#                                                employment_status  \
#                                                              max
# country_live
# Algeria        Self-employed (a person earning income directl...
# Argentina                                        Working student
# Armenia        Self-employed (a person earning income directl...
# Australia                                        Working student
# Austria                                          Working student
# ...                                                          ...
# United States                                    Working student
# Uruguay        Self-employed (a person earning income directl...
# Uzbekistan        Partially employed by a company / organization
# Venezuela                                        Working student
# Viet Nam                                         Working student
#
#                                                            \
#                                                       min
# country_live
# Algeria        Fully employed by a company / organization
# Argentina      Fully employed by a company / organization
# Armenia        Fully employed by a company / organization
# Australia      Fully employed by a company / organization
# Austria        Fully employed by a company / organization
# ...                                                   ...
# United States  Fully employed by a company / organization
# Uruguay        Fully employed by a company / organization
# Uzbekistan     Fully employed by a company / organization
# Venezuela      Fully employed by a company / organization
# Viet Nam       Fully employed by a company / organization
#
#                     first_learn_about_main_ide  \
#                                            max
# country_live
# Algeria        Technical review / Forum / Blog
# Argentina      Technical review / Forum / Blog
# Armenia        Technical review / Forum / Blog
# Australia      Technical review / Forum / Blog
# Austria        Technical review / Forum / Blog
# ...                                        ...
# United States  Technical review / Forum / Blog
# Uruguay        Technical review / Forum / Blog
# Uzbekistan     Technical review / Forum / Blog
# Venezuela      Technical review / Forum / Blog
# Viet Nam       Technical review / Forum / Blog
#
#                                                           ... python_years  \
#                                                      min  ...          max
# country_live                                              ...
# Algeria         Online learning platform / Online course  ...         11.0
# Argentina       Online learning platform / Online course  ...         11.0
# Armenia         Online learning platform / Online course  ...          6.0
# Australia       Online learning platform / Online course  ...         11.0
# Austria         Online learning platform / Online course  ...         11.0
# ...                                                  ...  ...          ...
# United States   Online learning platform / Online course  ...         11.0
# Uruguay         Online learning platform / Online course  ...         11.0
# Uzbekistan                                   Advertising  ...          3.0
# Venezuela       Online learning platform / Online course  ...         11.0
# Viet Nam        Online learning platform / Online course  ...          6.0
#
#                                                      several_projects  \
#                min                                                max
# country_live
# Algeria        1.0  Yes, I work on one main and several side projects
# Argentina      1.0  Yes, I work on one main and several side projects
# Armenia        1.0  Yes, I work on one main and several side projects
# Australia      1.0  Yes, I work on one main and several side projects
# Austria        1.0  Yes, I work on one main and several side projects
# ...            ...                                                ...
# United States  1.0  Yes, I work on one main and several side projects
# Uruguay        1.0  Yes, I work on one main and several side projects
# Uzbekistan     1.0  Yes, I work on one main and several side projects
# Venezuela      1.0  Yes, I work on one main and several side projects
# Viet Nam       1.0  Yes, I work on one main and several side projects
#
#                                                team_size      use_python_most  \
#                                            min       max min              max
# country_live
# Algeria        No,  I only work on one project        13   1  Web development
# Argentina      No,  I only work on one project        21   1  Web development
# Armenia        No,  I only work on one project        13   1  Web development
# Australia      No,  I only work on one project        41   1  Web development
# Austria        No,  I only work on one project        13   1  Web development
# ...                                        ...       ...  ..              ...
# United States  No,  I only work on one project        41   1  Web development
# Uruguay        No,  I only work on one project        13   2  Web development
# Uzbekistan     No,  I only work on one project         6   1          Unknown
# Venezuela      No,  I only work on one project        21   1  Web development
# Viet Nam       No,  I only work on one project        41   1  Web development
#
#                                                                   \
#                                                              min
# country_live
# Algeria                                            Data analysis
# Argentina                                          Data analysis
# Armenia        DevOps / System administration / Writing autom...
# Australia                                      Computer graphics
# Austria                                        Computer graphics
# ...                                                          ...
# United States                                  Computer graphics
# Uruguay                                            Data analysis
# Uzbekistan     DevOps / System administration / Writing autom...
# Venezuela                                          Data analysis
# Viet Nam                                       Computer graphics
#
#               years_of_coding
#                           max  min
# country_live
# Algeria                  11.0  1.0
# Argentina                11.0  1.0
# Armenia                  11.0  1.0
# Australia                11.0  1.0
# Austria                  11.0  1.0
# ...                       ...  ...
# United States            11.0  1.0
# Uruguay                  11.0  1.0
# Uzbekistan                6.0  1.0
# Venezuela                11.0  1.0
# Viet Nam                  6.0  1.0
#
# [76 rows x 38 columns]

# %%
(jb2
 .groupby('country_live')
 .agg([min, max]))
# Out:
#               age     are_you_datascientist       company_size        \
#               min max                   min   max          min   max
# country_live
# Algeria        18  60                 False  True            1  5000
# Argentina      18  60                 False  True            1  5000
# Armenia        18  30                 False  True            1  5000
# Australia      18  60                 False  True            1  5000
# Austria        18  50                 False  True            1  5000
# ...            ..  ..                   ...   ...          ...   ...
# United States  18  60                 False  True            1  5000
# Uruguay        21  40                 False  True            2  5000
# Uzbekistan     21  21                 False  True            1  5000
# Venezuela      18  50                 False  True            1  5000
# Viet Nam       18  60                 False  True            1  5000
#
#                                         employment_status  \
#                                                       min
# country_live
# Algeria        Fully employed by a company / organization
# Argentina      Fully employed by a company / organization
# Armenia        Fully employed by a company / organization
# Australia      Fully employed by a company / organization
# Austria        Fully employed by a company / organization
# ...                                                   ...
# United States  Fully employed by a company / organization
# Uruguay        Fully employed by a company / organization
# Uzbekistan     Fully employed by a company / organization
# Venezuela      Fully employed by a company / organization
# Viet Nam       Fully employed by a company / organization
#
#                                                                   \
#                                                              max
# country_live
# Algeria        Self-employed (a person earning income directl...
# Argentina                                        Working student
# Armenia        Self-employed (a person earning income directl...
# Australia                                        Working student
# Austria                                          Working student
# ...                                                          ...
# United States                                    Working student
# Uruguay        Self-employed (a person earning income directl...
# Uzbekistan        Partially employed by a company / organization
# Venezuela                                        Working student
# Viet Nam                                         Working student
#
#                               first_learn_about_main_ide  \
#                                                      min
# country_live
# Algeria         Online learning platform / Online course
# Argentina       Online learning platform / Online course
# Armenia         Online learning platform / Online course
# Australia       Online learning platform / Online course
# Austria         Online learning platform / Online course
# ...                                                  ...
# United States   Online learning platform / Online course
# Uruguay         Online learning platform / Online course
# Uzbekistan                                   Advertising
# Venezuela       Online learning platform / Online course
# Viet Nam        Online learning platform / Online course
#
#                                                 ...  \
#                                            max  ...
# country_live                                    ...
# Algeria        Technical review / Forum / Blog  ...
# Argentina      Technical review / Forum / Blog  ...
# Armenia        Technical review / Forum / Blog  ...
# Australia      Technical review / Forum / Blog  ...
# Austria        Technical review / Forum / Blog  ...
# ...                                        ...  ...
# United States  Technical review / Forum / Blog  ...
# Uruguay        Technical review / Forum / Blog  ...
# Uzbekistan     Technical review / Forum / Blog  ...
# Venezuela      Technical review / Forum / Blog  ...
# Viet Nam       Technical review / Forum / Blog  ...
#
#                               several_projects  \
#                                            min
# country_live
# Algeria        No,  I only work on one project
# Argentina      No,  I only work on one project
# Armenia        No,  I only work on one project
# Australia      No,  I only work on one project
# Austria        No,  I only work on one project
# ...                                        ...
# United States  No,  I only work on one project
# Uruguay        No,  I only work on one project
# Uzbekistan     No,  I only work on one project
# Venezuela      No,  I only work on one project
# Viet Nam       No,  I only work on one project
#
#                                                                  team_size  \
#                                                              max       min
# country_live
# Algeria        Yes, I work on one main and several side projects         1
# Argentina      Yes, I work on one main and several side projects         1
# Armenia        Yes, I work on one main and several side projects         1
# Australia      Yes, I work on one main and several side projects         1
# Austria        Yes, I work on one main and several side projects         1
# ...                                                          ...       ...
# United States  Yes, I work on one main and several side projects         1
# Uruguay        Yes, I work on one main and several side projects         2
# Uzbekistan     Yes, I work on one main and several side projects         1
# Venezuela      Yes, I work on one main and several side projects         1
# Viet Nam       Yes, I work on one main and several side projects         1
#
#                                                      use_python_most  \
#               max                                                min
# country_live
# Algeria        13                                      Data analysis
# Argentina      21                                      Data analysis
# Armenia        13  DevOps / System administration / Writing autom...
# Australia      41                                  Computer graphics
# Austria        13                                  Computer graphics
# ...            ..                                                ...
# United States  41                                  Computer graphics
# Uruguay        13                                      Data analysis
# Uzbekistan      6  DevOps / System administration / Writing autom...
# Venezuela      21                                      Data analysis
# Viet Nam       41                                  Computer graphics
#
#                                years_of_coding       python3_ver
#                            max             min   max         min  max
# country_live
# Algeria        Web development             1.0  11.0         3.5  3.9
# Argentina      Web development             1.0  11.0         3.6  3.9
# Armenia        Web development             1.0  11.0         3.6  3.9
# Australia      Web development             1.0  11.0         3.5  3.9
# Austria        Web development             1.0  11.0         3.5  3.9
# ...                        ...             ...   ...         ...  ...
# United States  Web development             1.0  11.0         3.5  3.9
# Uruguay        Web development             1.0  11.0         3.6  3.8
# Uzbekistan             Unknown             1.0   6.0         3.6  3.8
# Venezuela      Web development             1.0  11.0         3.5  3.8
# Viet Nam       Web development             1.0   6.0         3.5  3.9
#
# [76 rows x 38 columns]

# %%
(jb2
 .pivot_table(index='country_live',
              aggfunc={'age':['min','max'],
                       'team_size':'mean'}))
# Out:
#               age     team_size
#               max min      mean
# country_live
# Algeria        60  18  3.722222
# Argentina      60  18  4.146789
# Armenia        30  18  4.235294
# Australia      60  18  3.354015
# Austria        50  18  3.132812
# ...            ..  ..       ...
# United States  60  18  4.072673
# Uruguay        40  21  3.700000
# Uzbekistan     21  21  2.750000
# Venezuela      50  18  3.227273
# Viet Nam       60  18  4.666667
#
# [76 rows x 3 columns]

# %%
(jb2
 .groupby('country_live')
 .agg({'age':['min', 'max'],
       'team_size': 'mean'}))
# Out:
#               age     team_size
#               min max      mean
# country_live
# Algeria        18  60  3.722222
# Argentina      18  60  4.146789
# Armenia        18  30  4.235294
# Australia      18  60  3.354015
# Austria        18  50  3.132812
# ...            ..  ..       ...
# United States  18  60  4.072673
# Uruguay        21  40  3.700000
# Uzbekistan     21  21  2.750000
# Venezuela      18  50  3.227273
# Viet Nam       18  60  4.666667
#
# [76 rows x 3 columns]

# %%
(jb2
 .groupby('country_live')
 .agg(age_min=('age',min),
      age_max=('age',max),
      team_size_mean=('team_size','mean')))
# Out:
#                age_min  age_max  team_size_mean
# country_live
# Algeria             18       60        3.722222
# Argentina           18       60        4.146789
# Armenia             18       30        4.235294
# Australia           18       60        3.354015
# Austria             18       50        3.132812
# ...                ...      ...             ...
# United States       18       60        4.072673
# Uruguay             21       40        3.700000
# Uzbekistan          21       21        2.750000
# Venezuela           18       50        3.227273
# Viet Nam            18       60        4.666667
#
# [76 rows x 3 columns]

# %% [markdown]
# ## 27.5 Grouping by Hierarchy

# %%
jb2.pivot_table
