# %% [markdown]
# # Chapter 30

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 30.1 Melting Data

# %%
scores = pd.DataFrame ({
'age': [15, 16, 16, 15],
'name':['Adam', 'Bob', 'Dave', 'Fred'],
'test1': [95, 81, 89, None],
'test2': [80, 82, 84, 88],
'teacher': ['Ashby', 'Ashby', 'Jones', 'Jones']})

scores
# Out:
#    age  name  test1  test2 teacher
# 0   15  Adam   95.0     80   Ashby
# 1   16   Bob   81.0     82   Ashby
# 2   16  Dave   89.0     84   Jones
# 3   15  Fred    NaN     88   Jones

# %%
scores.melt(id_vars=['name', 'age'],
            value_vars=['test1', 'test2'])
# Out:
#    name  age variable  value
# 0  Adam   15    test1   95.0
# 1   Bob   16    test1   81.0
# 2  Dave   16    test1   89.0
# 3  Fred   15    test1    NaN
# 4  Adam   15    test2   80.0
# 5   Bob   16    test2   82.0
# 6  Dave   16    test2   84.0
# 7  Fred   15    test2   88.0

# %%
scores.melt(id_vars=['name', 'age'],
            value_vars=['test1', 'test2'],
            var_name='test', value_name='score')
# Out:
#    name  age   test  score
# 0  Adam   15  test1   95.0
# 1   Bob   16  test1   81.0
# 2  Dave   16  test1   89.0
# 3  Fred   15  test1    NaN
# 4  Adam   15  test2   80.0
# 5   Bob   16  test2   82.0
# 6  Dave   16  test2   84.0
# 7  Fred   15  test2   88.0

# %%
scores.melt(id_vars=['name', 'age', 'teacher'],
            value_vars=['test1', 'test2'],
            var_name='test', value_name='score')
# Out:
#    name  age teacher   test  score
# 0  Adam   15   Ashby  test1   95.0
# 1   Bob   16   Ashby  test1   81.0
# 2  Dave   16   Jones  test1   89.0
# 3  Fred   15   Jones  test1    NaN
# 4  Adam   15   Ashby  test2   80.0
# 5   Bob   16   Ashby  test2   82.0
# 6  Dave   16   Jones  test2   84.0
# 7  Fred   15   Jones  test2   88.0

# %% [markdown]
# ## 30.2 Un-melting Data

# %%
melted = scores.melt(id_vars=['name', 'age', 'teacher'],
                     value_vars=['test1', 'test2'],
                     var_name='test', value_name='score'
                     )
melted
# Out:
#    name  age teacher   test  score
# 0  Adam   15   Ashby  test1   95.0
# 1   Bob   16   Ashby  test1   81.0
# 2  Dave   16   Jones  test1   89.0
# 3  Fred   15   Jones  test1    NaN
# 4  Adam   15   Ashby  test2   80.0
# 5   Bob   16   Ashby  test2   82.0
# 6  Dave   16   Jones  test2   84.0
# 7  Fred   15   Jones  test2   88.0

# %%
(melted
 .pivot_table(index=['name', 'age', 'teacher'],
              columns='test', values='score')
 .reset_index()
)
# Out:
# test  name  age teacher  test1  test2
# 0     Adam   15   Ashby   95.0   80.0
# 1      Bob   16   Ashby   81.0   82.0
# 2     Dave   16   Jones   89.0   84.0
# 3     Fred   15   Jones    NaN   88.0

# %%
(melted
 .groupby(['name', 'age', 'teacher', 'test'])
 .score
 .mean()
 .unstack()
 .reset_index()
)
# Out:
# test  name  age teacher  test1  test2
# 0     Adam   15   Ashby   95.0   80.0
# 1      Bob   16   Ashby   81.0   82.0
# 2     Dave   16   Jones   89.0   84.0
# 3     Fred   15   Jones    NaN   88.0

# %% [markdown]
# ## 30.3 Transposing Data

# %%
jb2 = pd.read_csv('data/jet_brains_python_2020_survey_data_cleaned.csv',
                  index_col=0)
jb2
# Out:
#        age are_you_datascientist  company_size        country_live  \
# 1       21                  True          5000               India
# 2       30                 False          5000       United States
# 10      21                 False            51       Other country
# 11      21                  True            51       United States
# 13      30                  True          5000             Belgium
# ...    ...                   ...           ...                 ...
# 54456   30                 False          1001              Turkey
# 54457   21                 False             2  Russian Federation
# 54459   21                 False             1  Russian Federation
# 54460   30                  True            51               Spain
# 54461   21                 False            11             Algeria
#
#                                        employment_status  \
# 1             Fully employed by a company / organization
# 2             Fully employed by a company / organization
# 10            Fully employed by a company / organization
# 11            Fully employed by a company / organization
# 13            Fully employed by a company / organization
# ...                                                  ...
# 54456         Fully employed by a company / organization
# 54457         Fully employed by a company / organization
# 54459  Self-employed (a person earning income directl...
# 54460         Fully employed by a company / organization
# 54461         Fully employed by a company / organization
#
#                       first_learn_about_main_ide how_often_use_main_ide  \
# 1                            School / University                  Daily
# 2                             Friend / Colleague                  Daily
# 10                           School / University                  Daily
# 11      Online learning platform / Online course                  Daily
# 13                                Social network                  Daily
# ...                                          ...                    ...
# 54456                         Friend / Colleague                  Daily
# 54457                        School / University                  Daily
# 54459                         Friend / Colleague                  Daily
# 54460                             Search engines                  Daily
# 54461   Online learning platform / Online course                  Daily
#
#                            ide_main is_python_main  \
# 1                           VS Code            Yes
# 2                               Vim            Yes
# 10                    IntelliJ IDEA            Yes
# 11        PyCharm Community Edition            Yes
# 13                          VS Code            Yes
# ...                             ...            ...
# 54456     PyCharm Community Edition            Yes
# 54457                           Vim            Yes
# 54459  PyCharm Professional Edition            Yes
# 54460                         Other            Yes
# 54461                       VS Code            Yes
#
#                                         job_team               main_purposes  \
# 1                                 Work in a team  Both for work and personal
# 2      Work on your own project(s) independently  Both for work and personal
# 10                                Work in a team  Both for work and personal
# 11                                Work in a team  Both for work and personal
# 13                                Work in a team  Both for work and personal
# ...                                          ...                         ...
# 54456  Work on your own project(s) independently  Both for work and personal
# 54457  Work on your own project(s) independently  Both for work and personal
# 54459                             Work in a team  Both for work and personal
# 54460  Work on your own project(s) independently  Both for work and personal
# 54461                             Work in a team  Both for work and personal
#
#                 missing_features_main_ide  nps_main_ide  python_years  \
# 1      No, it has all the features I need           8.0           3.0
# 2      No, it has all the features I need          10.0           3.0
# 10     No, it has all the features I need          10.0           1.0
# 11     No, it has all the features I need           9.0           3.0
# 13     No, it has all the features I need          10.0           6.0
# ...                                   ...           ...           ...
# 54456  No, it has all the features I need           9.0           1.0
# 54457  No, it has all the features I need          10.0           6.0
# 54459  No, it has all the features I need          10.0           3.0
# 54460                  Yes – Please list:           3.0           6.0
# 54461  No, it has all the features I need          10.0           1.0
#
#       python3_version_most                                   several_projects  \
# 1               Python 3_6  Yes, I work on one main and several side projects
# 2               Python 3_6  Yes, I work on one main and several side projects
# 10              Python 3_8  Yes, I work on one main and several side projects
# 11              Python 3_9             Yes, I work on many different projects
# 13              Python 3_7             Yes, I work on many different projects
# ...                    ...                                                ...
# 54456           Python 3_6             Yes, I work on many different projects
# 54457           Python 3_6             Yes, I work on many different projects
# 54459           Python 3_7             Yes, I work on many different projects
# 54460           Python 3_7             Yes, I work on many different projects
# 54461           Python 3_8             Yes, I work on many different projects
#
#        team_size                                    use_python_most  \
# 1              2                               Software prototyping
# 2              4  DevOps / System administration / Writing autom...
# 10             2                                    Web development
# 11             2                                      Data analysis
# 13             2                                      Data analysis
# ...          ...                                                ...
# 54456          5                                   Machine learning
# 54457          2                                      Data analysis
# 54459          1                                    Web development
# 54460          4                                      Data analysis
# 54461          2                                            Unknown
#
#        years_of_coding  python3_ver
# 1                  3.0          3.6
# 2                  3.0          3.6
# 10                 1.0          3.8
# 11                 3.0          3.9
# 13                 3.0          3.7
# ...                ...          ...
# 54456              6.0          3.6
# 54457              1.0          3.6
# 54459              6.0          3.7
# 54460              3.0          3.7
# 54461              1.0          3.8
#
# [13711 rows x 20 columns]

# %%
jb2.head().T
# Out:
#                                                                            1   \
# age                                                                        21
# are_you_datascientist                                                    True
# company_size                                                             5000
# country_live                                                            India
# employment_status                  Fully employed by a company / organization
# first_learn_about_main_ide                                School / University
# how_often_use_main_ide                                                  Daily
# ide_main                                                              VS Code
# is_python_main                                                            Yes
# job_team                                                       Work in a team
# main_purposes                                      Both for work and personal
# missing_features_main_ide                  No, it has all the features I need
# nps_main_ide                                                              8.0
# python_years                                                              3.0
# python3_version_most                                               Python 3_6
# several_projects            Yes, I work on one main and several side projects
# team_size                                                                   2
# use_python_most                                          Software prototyping
# years_of_coding                                                           3.0
# python3_ver                                                               3.6
#
#                                                                            2   \
# age                                                                        30
# are_you_datascientist                                                   False
# company_size                                                             5000
# country_live                                                    United States
# employment_status                  Fully employed by a company / organization
# first_learn_about_main_ide                                 Friend / Colleague
# how_often_use_main_ide                                                  Daily
# ide_main                                                                  Vim
# is_python_main                                                            Yes
# job_team                            Work on your own project(s) independently
# main_purposes                                      Both for work and personal
# missing_features_main_ide                  No, it has all the features I need
# nps_main_ide                                                             10.0
# python_years                                                              3.0
# python3_version_most                                               Python 3_6
# several_projects            Yes, I work on one main and several side projects
# team_size                                                                   4
# use_python_most             DevOps / System administration / Writing autom...
# years_of_coding                                                           3.0
# python3_ver                                                               3.6
#
#                                                                            10  \
# age                                                                        21
# are_you_datascientist                                                   False
# company_size                                                               51
# country_live                                                    Other country
# employment_status                  Fully employed by a company / organization
# first_learn_about_main_ide                                School / University
# how_often_use_main_ide                                                  Daily
# ide_main                                                        IntelliJ IDEA
# is_python_main                                                            Yes
# job_team                                                       Work in a team
# main_purposes                                      Both for work and personal
# missing_features_main_ide                  No, it has all the features I need
# nps_main_ide                                                             10.0
# python_years                                                              1.0
# python3_version_most                                               Python 3_8
# several_projects            Yes, I work on one main and several side projects
# team_size                                                                   2
# use_python_most                                               Web development
# years_of_coding                                                           1.0
# python3_ver                                                               3.8
#
#                                                                     11  \
# age                                                                 21
# are_you_datascientist                                             True
# company_size                                                        51
# country_live                                             United States
# employment_status           Fully employed by a company / organization
# first_learn_about_main_ide    Online learning platform / Online course
# how_often_use_main_ide                                           Daily
# ide_main                                     PyCharm Community Edition
# is_python_main                                                     Yes
# job_team                                                Work in a team
# main_purposes                               Both for work and personal
# missing_features_main_ide           No, it has all the features I need
# nps_main_ide                                                       9.0
# python_years                                                       3.0
# python3_version_most                                        Python 3_9
# several_projects                Yes, I work on many different projects
# team_size                                                            2
# use_python_most                                          Data analysis
# years_of_coding                                                    3.0
# python3_ver                                                        3.9
#
#                                                                     13
# age                                                                 30
# are_you_datascientist                                             True
# company_size                                                      5000
# country_live                                                   Belgium
# employment_status           Fully employed by a company / organization
# first_learn_about_main_ide                              Social network
# how_often_use_main_ide                                           Daily
# ide_main                                                       VS Code
# is_python_main                                                     Yes
# job_team                                                Work in a team
# main_purposes                               Both for work and personal
# missing_features_main_ide           No, it has all the features I need
# nps_main_ide                                                      10.0
# python_years                                                       6.0
# python3_version_most                                        Python 3_7
# several_projects                Yes, I work on many different projects
# team_size                                                            2
# use_python_most                                          Data analysis
# years_of_coding                                                    3.0
# python3_ver                                                        3.7

# %% [markdown]
# ## 30.4 Stacking & Unstacking

# %%
jb2
# Out:
#        age are_you_datascientist  company_size        country_live  \
# 1       21                  True          5000               India
# 2       30                 False          5000       United States
# 10      21                 False            51       Other country
# 11      21                  True            51       United States
# 13      30                  True          5000             Belgium
# ...    ...                   ...           ...                 ...
# 54456   30                 False          1001              Turkey
# 54457   21                 False             2  Russian Federation
# 54459   21                 False             1  Russian Federation
# 54460   30                  True            51               Spain
# 54461   21                 False            11             Algeria
#
#                                        employment_status  \
# 1             Fully employed by a company / organization
# 2             Fully employed by a company / organization
# 10            Fully employed by a company / organization
# 11            Fully employed by a company / organization
# 13            Fully employed by a company / organization
# ...                                                  ...
# 54456         Fully employed by a company / organization
# 54457         Fully employed by a company / organization
# 54459  Self-employed (a person earning income directl...
# 54460         Fully employed by a company / organization
# 54461         Fully employed by a company / organization
#
#                       first_learn_about_main_ide how_often_use_main_ide  \
# 1                            School / University                  Daily
# 2                             Friend / Colleague                  Daily
# 10                           School / University                  Daily
# 11      Online learning platform / Online course                  Daily
# 13                                Social network                  Daily
# ...                                          ...                    ...
# 54456                         Friend / Colleague                  Daily
# 54457                        School / University                  Daily
# 54459                         Friend / Colleague                  Daily
# 54460                             Search engines                  Daily
# 54461   Online learning platform / Online course                  Daily
#
#                            ide_main is_python_main  \
# 1                           VS Code            Yes
# 2                               Vim            Yes
# 10                    IntelliJ IDEA            Yes
# 11        PyCharm Community Edition            Yes
# 13                          VS Code            Yes
# ...                             ...            ...
# 54456     PyCharm Community Edition            Yes
# 54457                           Vim            Yes
# 54459  PyCharm Professional Edition            Yes
# 54460                         Other            Yes
# 54461                       VS Code            Yes
#
#                                         job_team               main_purposes  \
# 1                                 Work in a team  Both for work and personal
# 2      Work on your own project(s) independently  Both for work and personal
# 10                                Work in a team  Both for work and personal
# 11                                Work in a team  Both for work and personal
# 13                                Work in a team  Both for work and personal
# ...                                          ...                         ...
# 54456  Work on your own project(s) independently  Both for work and personal
# 54457  Work on your own project(s) independently  Both for work and personal
# 54459                             Work in a team  Both for work and personal
# 54460  Work on your own project(s) independently  Both for work and personal
# 54461                             Work in a team  Both for work and personal
#
#                 missing_features_main_ide  nps_main_ide  python_years  \
# 1      No, it has all the features I need           8.0           3.0
# 2      No, it has all the features I need          10.0           3.0
# 10     No, it has all the features I need          10.0           1.0
# 11     No, it has all the features I need           9.0           3.0
# 13     No, it has all the features I need          10.0           6.0
# ...                                   ...           ...           ...
# 54456  No, it has all the features I need           9.0           1.0
# 54457  No, it has all the features I need          10.0           6.0
# 54459  No, it has all the features I need          10.0           3.0
# 54460                  Yes – Please list:           3.0           6.0
# 54461  No, it has all the features I need          10.0           1.0
#
#       python3_version_most                                   several_projects  \
# 1               Python 3_6  Yes, I work on one main and several side projects
# 2               Python 3_6  Yes, I work on one main and several side projects
# 10              Python 3_8  Yes, I work on one main and several side projects
# 11              Python 3_9             Yes, I work on many different projects
# 13              Python 3_7             Yes, I work on many different projects
# ...                    ...                                                ...
# 54456           Python 3_6             Yes, I work on many different projects
# 54457           Python 3_6             Yes, I work on many different projects
# 54459           Python 3_7             Yes, I work on many different projects
# 54460           Python 3_7             Yes, I work on many different projects
# 54461           Python 3_8             Yes, I work on many different projects
#
#        team_size                                    use_python_most  \
# 1              2                               Software prototyping
# 2              4  DevOps / System administration / Writing autom...
# 10             2                                    Web development
# 11             2                                      Data analysis
# 13             2                                      Data analysis
# ...          ...                                                ...
# 54456          5                                   Machine learning
# 54457          2                                      Data analysis
# 54459          1                                    Web development
# 54460          4                                      Data analysis
# 54461          2                                            Unknown
#
#        years_of_coding  python3_ver
# 1                  3.0          3.6
# 2                  3.0          3.6
# 10                 1.0          3.8
# 11                 3.0          3.9
# 13                 3.0          3.7
# ...                ...          ...
# 54456              6.0          3.6
# 54457              1.0          3.6
# 54459              6.0          3.7
# 54460              3.0          3.7
# 54461              1.0          3.8
#
# [13711 rows x 20 columns]

# %%
(jb2
 .groupby(['country_live', 'are_you_datascientist'])
 .size()
 .unstack()
)
# Out:
# are_you_datascientist   False  Other   True
# country_live
# Algeria                  12.0    1.0    5.0
# Argentina                89.0    4.0   16.0
# Armenia                  15.0    NaN    2.0
# Australia               210.0   14.0   50.0
# Austria                  93.0    3.0   32.0
# ...                       ...    ...    ...
# United States          2008.0  100.0  589.0
# Uruguay                  10.0    1.0    9.0
# Uzbekistan                3.0    NaN    1.0
# Venezuela                16.0    2.0    4.0
# Viet Nam                 16.0    3.0   14.0
#
# [76 rows x 3 columns]

# %%
(jb2
 .groupby(['country_live', 'are_you_datascientist'])
 .size()
 .unstack('country_live')
)
# Out:
# country_live           Algeria  Argentina  Armenia  Australia  Austria  \
# are_you_datascientist
# False                     12.0       89.0     15.0      210.0     93.0
# Other                      1.0        4.0      NaN       14.0      3.0
# True                       5.0       16.0      2.0       50.0     32.0
#
# country_live           Bangladesh  Belarus  Belgium  Brazil  Bulgaria  ...  \
# are_you_datascientist                                                  ...
# False                        22.0     41.0     92.0   301.0      30.0  ...
# Other                         1.0      2.0      2.0    20.0       3.0  ...
# True                         10.0      4.0     41.0   108.0       8.0  ...
#
# country_live           Tunisia  Turkey  Ukraine  United Arab Emirates  \
# are_you_datascientist
# False                      6.0    65.0    165.0                  13.0
# Other                      NaN     4.0      9.0                   NaN
# True                       1.0    30.0     23.0                   4.0
#
# country_live           United Kingdom  United States  Uruguay  Uzbekistan  \
# are_you_datascientist
# False                           521.0         2008.0     10.0         3.0
# Other                            36.0          100.0      1.0         NaN
# True                            142.0          589.0      9.0         1.0
#
# country_live           Venezuela  Viet Nam
# are_you_datascientist
# False                       16.0      16.0
# Other                        2.0       3.0
# True                         4.0      14.0
#
# [3 rows x 76 columns]

# %% [markdown]
# ## 30.5 Stacking

# %%
(jb2
 .pivot_table(index='country_live',
              aggfunc={'age': ['min', 'max'],
                       'company_size': ['min', 'max']}) 
)
# Out:
#               age     company_size
#               max min          max min
# country_live
# Algeria        60  18         5000   1
# Argentina      60  18         5000   1
# Armenia        30  18         5000   1
# Australia      60  18         5000   1
# Austria        50  18         5000   1
# ...            ..  ..          ...  ..
# United States  60  18         5000   1
# Uruguay        40  21         5000   2
# Uzbekistan     21  21         5000   1
# Venezuela      50  18         5000   1
# Viet Nam       60  18         5000   1
#
# [76 rows x 4 columns]

# %%
(jb2
 .pivot_table(index='country_live',
              aggfunc={'age': ['min', 'max'],
                       'company_size': ['min', 'max']})
 .stack(1) 
 .swaplevel()
)
# Out:
#                   age  company_size
#     country_live
# max Algeria        60          5000
# min Algeria        18             1
# max Argentina      60          5000
# min Argentina      18             1
# max Armenia        30          5000
# ...               ...           ...
# min Uzbekistan     21             1
# max Venezuela      50          5000
# min Venezuela      18             1
# max Viet Nam       60          5000
# min Viet Nam       18             1
#
# [152 rows x 2 columns]

# %% [markdown]
# ## 30.6 Flattening Hierarchical Indexes and Columns

# %%
(jb2
 .groupby(['country_live', 'age'])
 .mean()
 .reset_index()
)
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_72354/1229234460.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
#     country_live  age  company_size  nps_main_ide  python_years  team_size  \
# 0        Algeria   18      2.000000     10.000000      1.000000   2.500000
# 1        Algeria   21    725.428571      7.142857      1.571429   3.142857
# 2        Algeria   30      1.600000      8.400000      2.800000   1.800000
# 3        Algeria   40   1674.000000      8.000000      5.000000   6.000000
# 4        Algeria   60   5000.000000      6.000000     11.000000  13.000000
# ..           ...  ...           ...           ...           ...        ...
# 355     Viet Nam   18     51.000000     10.000000      1.000000   2.000000
# 356     Viet Nam   21    348.346154      8.923077      2.192308   4.884615
# 357     Viet Nam   30    266.250000      9.000000      3.250000   5.500000
# 358     Viet Nam   40     51.000000      9.000000      3.000000   2.000000
# 359     Viet Nam   60      1.000000      8.000000      3.000000   1.000000
#
#      years_of_coding  python3_ver
# 0           6.000000     3.650000
# 1           2.428571     3.757143
# 2           3.800000     3.700000
# 3           6.666667     3.766667
# 4          11.000000     3.900000
# ..               ...          ...
# 355         1.000000     3.700000
# 356         1.923077     3.711538
# 357         3.500000     3.750000
# 358         6.000000     3.800000
# 359         1.000000     3.900000
#
# [360 rows x 8 columns]

# %%
(jb2
 .groupby(['country_live', 'age'], as_index=False)
 .mean()
)
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_72354/1744890343.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
#     country_live  age  company_size  nps_main_ide  python_years  team_size  \
# 0        Algeria   18      2.000000     10.000000      1.000000   2.500000
# 1        Algeria   21    725.428571      7.142857      1.571429   3.142857
# 2        Algeria   30      1.600000      8.400000      2.800000   1.800000
# 3        Algeria   40   1674.000000      8.000000      5.000000   6.000000
# 4        Algeria   60   5000.000000      6.000000     11.000000  13.000000
# ..           ...  ...           ...           ...           ...        ...
# 355     Viet Nam   18     51.000000     10.000000      1.000000   2.000000
# 356     Viet Nam   21    348.346154      8.923077      2.192308   4.884615
# 357     Viet Nam   30    266.250000      9.000000      3.250000   5.500000
# 358     Viet Nam   40     51.000000      9.000000      3.000000   2.000000
# 359     Viet Nam   60      1.000000      8.000000      3.000000   1.000000
#
#      years_of_coding  python3_ver
# 0           6.000000     3.650000
# 1           2.428571     3.757143
# 2           3.800000     3.700000
# 3           6.666667     3.766667
# 4          11.000000     3.900000
# ..               ...          ...
# 355         1.000000     3.700000
# 356         1.923077     3.711538
# 357         3.500000     3.750000
# 358         6.000000     3.800000
# 359         1.000000     3.900000
#
# [360 rows x 8 columns]

# %%
(jb2
 .groupby(['country_live', 'age'])
 .mean()
 .unstack()
)
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_72354/889751193.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
#               company_size                                         \
# age                     18           21           30           40
# country_live
# Algeria               2.00   725.428571     1.600000  1674.000000
# Argentina            51.00   459.789474  1229.568182  1641.350000
# Armenia              11.00  1015.461538   337.666667          NaN
# Australia             4.25  1055.689655  1554.081818  1370.126984
# Austria              11.00   785.258065   853.741935   664.409091
# ...                    ...          ...          ...          ...
# United States       707.40  1640.298805  1644.012476  1764.550209
# Uruguay                NaN    31.000000   408.076923  1001.000000
# Uzbekistan             NaN  1265.750000          NaN          NaN
# Venezuela             2.00    25.100000     3.750000    13.400000
# Viet Nam             51.00   348.346154   266.250000    51.000000
#
#                                         nps_main_ide                      \
# age                     50           60           18        21        30
# country_live
# Algeria                NaN  5000.000000       10.000  7.142857  8.400000
# Argentina       241.000000     2.000000       10.000  8.710526  8.659091
# Armenia                NaN          NaN       10.000  9.000000  9.666667
# Australia      1527.833333   628.888889        8.500  8.637931  8.836364
# Austria         767.750000          NaN       10.000  8.677419  8.806452
# ...                    ...          ...          ...       ...       ...
# United States  1947.022727  1849.525000        9.225  8.948207  8.904990
# Uruguay                NaN          NaN          NaN  9.500000  9.076923
# Uzbekistan             NaN          NaN          NaN  9.750000       NaN
# Venezuela      2525.500000          NaN        8.000  9.800000  7.500000
# Viet Nam               NaN     1.000000       10.000  8.923077  9.000000
#
#                           ... years_of_coding                        \
# age                   40  ...              30         40         50
# country_live              ...
# Algeria         8.000000  ...        3.800000   6.666667        NaN
# Argentina       8.900000  ...        5.363636   9.200000  11.000000
# Armenia              NaN  ...        5.000000        NaN        NaN
# Australia       8.555556  ...        6.327273   8.920635  10.066667
# Austria         9.000000  ...        5.241935   7.772727  10.583333
# ...                  ...  ...             ...        ...        ...
# United States   8.920502  ...        6.078695   8.667364   9.905303
# Uruguay        10.000000  ...        6.307692   3.000000        NaN
# Uzbekistan           NaN  ...             NaN        NaN        NaN
# Venezuela       8.600000  ...        5.000000  10.000000   8.500000
# Viet Nam        9.000000  ...        3.500000   6.000000        NaN
#
#                          python3_ver                                          \
# age                   60          18        21        30        40        50
# country_live
# Algeria        11.000000       3.650  3.757143  3.700000  3.766667       NaN
# Argentina      11.000000       3.700  3.760526  3.743182  3.730000  3.720000
# Armenia              NaN       3.800  3.784615  3.766667       NaN       NaN
# Australia      10.444444       3.750  3.739655  3.730000  3.720635  3.756667
# Austria              NaN       3.800  3.729032  3.729032  3.745455  3.700000
# ...                  ...         ...       ...       ...       ...       ...
# United States  10.441667       3.775  3.736388  3.733685  3.742469  3.742045
# Uruguay              NaN         NaN  3.750000  3.746154  3.800000       NaN
# Uzbekistan           NaN         NaN  3.725000       NaN       NaN       NaN
# Venezuela            NaN       3.800  3.720000  3.650000  3.740000  3.800000
# Viet Nam        1.000000       3.700  3.711538  3.750000  3.800000       NaN
#
#
# age                  60
# country_live
# Algeria        3.900000
# Argentina      3.800000
# Armenia             NaN
# Australia      3.777778
# Austria             NaN
# ...                 ...
# United States  3.742500
# Uruguay             NaN
# Uzbekistan          NaN
# Venezuela           NaN
# Viet Nam       3.900000
#
# [76 rows x 36 columns]

# %%
def flatten_cols(df):
    cols = ['_'.join(map(str, vals))
            for vals in df.columns.to_flat_index()]
    df.columns = cols
    return df

# %%
(jb2
 .groupby(['country_live', 'age'])
 .mean()
 .unstack()
).columns#.to_flat_index()
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_72354/757340319.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
# MultiIndex([(   'company_size', 18),
#             (   'company_size', 21),
#             (   'company_size', 30),
#             (   'company_size', 40),
#             (   'company_size', 50),
#             (   'company_size', 60),
#             (   'nps_main_ide', 18),
#             (   'nps_main_ide', 21),
#             (   'nps_main_ide', 30),
#             (   'nps_main_ide', 40),
#             (   'nps_main_ide', 50),
#             (   'nps_main_ide', 60),
#             (   'python_years', 18),
#             (   'python_years', 21),
#             (   'python_years', 30),
#             (   'python_years', 40),
#             (   'python_years', 50),
#             (   'python_years', 60),
#             (      'team_size', 18),
#             (      'team_size', 21),
#             (      'team_size', 30),
#             (      'team_size', 40),
#             (      'team_size', 50),
#             (      'team_size', 60),
#             ('years_of_coding', 18),
#             ('years_of_coding', 21),
#             ('years_of_coding', 30),
#             ('years_of_coding', 40),
#             ('years_of_coding', 50),
#             ('years_of_coding', 60),
#             (    'python3_ver', 18),
#             (    'python3_ver', 21),
#             (    'python3_ver', 30),
#             (    'python3_ver', 40),
#             (    'python3_ver', 50),
#             (    'python3_ver', 60)],
#            names=[None, 'age'])

# %%
(jb2
 .groupby(['country_live', 'age'])
 .mean()
 .unstack()
 .pipe(flatten_cols)
)
# Out:
# /var/folders/gg/0m4l7pvs5zq9d8p4tzflypdc0000gn/T/ipykernel_72354/3692307684.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
#                company_size_18  company_size_21  company_size_30  \
# country_live
# Algeria                   2.00       725.428571         1.600000
# Argentina                51.00       459.789474      1229.568182
# Armenia                  11.00      1015.461538       337.666667
# Australia                 4.25      1055.689655      1554.081818
# Austria                  11.00       785.258065       853.741935
# ...                        ...              ...              ...
# United States           707.40      1640.298805      1644.012476
# Uruguay                    NaN        31.000000       408.076923
# Uzbekistan                 NaN      1265.750000              NaN
# Venezuela                 2.00        25.100000         3.750000
# Viet Nam                 51.00       348.346154       266.250000
#
#                company_size_40  company_size_50  company_size_60  \
# country_live
# Algeria            1674.000000              NaN      5000.000000
# Argentina          1641.350000       241.000000         2.000000
# Armenia                    NaN              NaN              NaN
# Australia          1370.126984      1527.833333       628.888889
# Austria             664.409091       767.750000              NaN
# ...                        ...              ...              ...
# United States      1764.550209      1947.022727      1849.525000
# Uruguay            1001.000000              NaN              NaN
# Uzbekistan                 NaN              NaN              NaN
# Venezuela            13.400000      2525.500000              NaN
# Viet Nam             51.000000              NaN         1.000000
#
#                nps_main_ide_18  nps_main_ide_21  nps_main_ide_30  \
# country_live
# Algeria                 10.000         7.142857         8.400000
# Argentina               10.000         8.710526         8.659091
# Armenia                 10.000         9.000000         9.666667
# Australia                8.500         8.637931         8.836364
# Austria                 10.000         8.677419         8.806452
# ...                        ...              ...              ...
# United States            9.225         8.948207         8.904990
# Uruguay                    NaN         9.500000         9.076923
# Uzbekistan                 NaN         9.750000              NaN
# Venezuela                8.000         9.800000         7.500000
# Viet Nam                10.000         8.923077         9.000000
#
#                nps_main_ide_40  ...  years_of_coding_30  years_of_coding_40  \
# country_live                    ...
# Algeria               8.000000  ...            3.800000            6.666667
# Argentina             8.900000  ...            5.363636            9.200000
# Armenia                    NaN  ...            5.000000                 NaN
# Australia             8.555556  ...            6.327273            8.920635
# Austria               9.000000  ...            5.241935            7.772727
# ...                        ...  ...                 ...                 ...
# United States         8.920502  ...            6.078695            8.667364
# Uruguay              10.000000  ...            6.307692            3.000000
# Uzbekistan                 NaN  ...                 NaN                 NaN
# Venezuela             8.600000  ...            5.000000           10.000000
# Viet Nam              9.000000  ...            3.500000            6.000000
#
#                years_of_coding_50  years_of_coding_60  python3_ver_18  \
# country_live
# Algeria                       NaN           11.000000           3.650
# Argentina               11.000000           11.000000           3.700
# Armenia                       NaN                 NaN           3.800
# Australia               10.066667           10.444444           3.750
# Austria                 10.583333                 NaN           3.800
# ...                           ...                 ...             ...
# United States            9.905303           10.441667           3.775
# Uruguay                       NaN                 NaN             NaN
# Uzbekistan                    NaN                 NaN             NaN
# Venezuela                8.500000                 NaN           3.800
# Viet Nam                      NaN            1.000000           3.700
#
#                python3_ver_21  python3_ver_30  python3_ver_40  python3_ver_50  \
# country_live
# Algeria              3.757143        3.700000        3.766667             NaN
# Argentina            3.760526        3.743182        3.730000        3.720000
# Armenia              3.784615        3.766667             NaN             NaN
# Australia            3.739655        3.730000        3.720635        3.756667
# Austria              3.729032        3.729032        3.745455        3.700000
# ...                       ...             ...             ...             ...
# United States        3.736388        3.733685        3.742469        3.742045
# Uruguay              3.750000        3.746154        3.800000             NaN
# Uzbekistan           3.725000             NaN             NaN             NaN
# Venezuela            3.720000        3.650000        3.740000        3.800000
# Viet Nam             3.711538        3.750000        3.800000             NaN
#
#                python3_ver_60
# country_live
# Algeria              3.900000
# Argentina            3.800000
# Armenia                   NaN
# Australia            3.777778
# Austria                   NaN
# ...                       ...
# United States        3.742500
# Uruguay                   NaN
# Uzbekistan                NaN
# Venezuela                 NaN
# Viet Nam             3.900000
#
# [76 rows x 36 columns]
