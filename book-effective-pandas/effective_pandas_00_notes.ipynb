# %% [markdown]
# # Effective Pandas

# %% [markdown]
# ## Link to Github Repo
# https://github.com/mattharrison/effective_pandas_book

# %% [markdown]
# # Notes for Effective Pandas Book

# %% [markdown]
# ## Questions

# %% [markdown]
# 1. **Chapter 10, page 94**.  Why use underscore for variable in lambda function (i.e., `lambda: s_: s_ > 3`)?
