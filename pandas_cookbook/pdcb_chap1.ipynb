# %% [markdown]
# # Chapter 1 - Pandas Foundations

# %%
import pandas as pd
import numpy as np

# %%
movies_url = 'https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/movie.csv'

# %%
movies = pd.read_csv(movies_url)
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 4911  ...                  6.0  English   Canada             NaN          NaN
# 4912  ...                359.0  English      USA           TV-14          NaN
# 4913  ...                  3.0  English      USA             NaN       1400.0
# 4914  ...                  9.0  English      USA           PG-13          NaN
# 4915  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
# 4913      2013.0                    0.0        6.3           NaN
# 4914      2012.0                  719.0        6.3          2.35
# 4915      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 4911                   84
# 4912                32000
# 4913                   16
# 4914                  660
# 4915                  456
#
# [4916 rows x 28 columns]

# %%
movies.to_numpy()
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
movies.index.to_numpy()
# Out:
# array([   0,    1,    2, ..., 4913, 4914, 4915])

# %%
movies.columns.to_numpy()
# Out:
# array(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'], dtype=object)

# %%
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
movies.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# Name: count, dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
#  13  cast_total_facebook_likes  4916 non-null   int64
#  14  actor_3_name               4893 non-null   object
#  15  facenumber_in_poster       4903 non-null   float64
#  16  plot_keywords              4764 non-null   object
#  17  movie_imdb_link            4916 non-null   object
#  18  num_user_for_reviews       4895 non-null   float64
#  19  language                   4902 non-null   object
#  20  country                    4911 non-null   object
#  21  content_rating             4616 non-null   object
#  22  budget                     4432 non-null   float64
#  23  title_year                 4810 non-null   float64
#  24  actor_2_facebook_likes     4903 non-null   float64
#  25  imdb_score                 4916 non-null   float64
#  26  aspect_ratio               4590 non-null   float64
#  27  movie_facebook_likes       4916 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
movies.director_name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies.loc[:, "director_name"]
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies.iloc[:,1]
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
def show_df(df_):
    print(f'df size = {df_.size}')
    print(f'df count = {df_.count()}')
    # display(df_.describe())
    return df_
    
(movies
.director_name
.value_counts(normalize=True)
.pipe(show_df)
)
# Out:
# df size = 2397
# df count = 2397
# director_name
# Steven Spielberg    0.005401
# Woody Allen         0.004570
# Martin Scorsese     0.004155
# Clint Eastwood      0.004155
# Ridley Scott        0.003324
#                       ...
# John Putch          0.000208
# Luca Guadagnino     0.000208
# Sam Fell            0.000208
# Dan Fogelman        0.000208
# Daniel Hsia         0.000208
# Name: proportion, Length: 2397, dtype: float64

# %%
movies.director_name.hasnans
# Out:
# True

# %%
movies.query('director_name.isna()')
# Out:
#                 color director_name  num_critic_for_reviews  duration  \
# 176             Color           NaN                    21.0      60.0
# 257             Color           NaN                    29.0      60.0
# 398             Color           NaN                   103.0      44.0
# 453               NaN           NaN                    95.0      54.0
# 473   Black and White           NaN                    31.0      25.0
# ...               ...           ...                     ...       ...
# 4683            Color           NaN                    75.0      60.0
# 4688            Color           NaN                    11.0      22.0
# 4704            Color           NaN                    23.0      43.0
# 4752            Color           NaN                    11.0      58.0
# 4912            Color           NaN                    43.0      43.0
#
#       director_facebook_likes  actor_3_facebook_likes           actor_2_name  \
# 176                       NaN                   184.0  Philip Michael Thomas
# 257                       NaN                   432.0          Dirk Benedict
# 398                       NaN                   148.0         Scott Thompson
# 453                       NaN                     0.0          Royce Johnson
# 473                       NaN                   474.0        Agnes Moorehead
# ...                       ...                     ...                    ...
# 4683                      NaN                   833.0               Masi Oka
# 4688                      NaN                     6.0              Ron Lynch
# 4704                      NaN                   576.0       Tracy Spiridakos
# 4752                      NaN                   250.0           James Norton
# 4912                      NaN                   319.0          Valorie Curry
#
#       actor_1_facebook_likes  gross  \
# 176                    982.0    NaN
# 257                    669.0    NaN
# 398                    544.0    NaN
# 453                    577.0    NaN
# 473                   1000.0    NaN
# ...                      ...    ...
# 4683                  1000.0    NaN
# 4688                    59.0    NaN
# 4704                  2000.0    NaN
# 4752                   887.0    NaN
# 4912                   841.0    NaN
#
#                                             genres  ... num_user_for_reviews  \
# 176            Action|Crime|Drama|Mystery|Thriller  ...                 74.0
# 257                         Action|Adventure|Crime  ...                 97.0
# 398            Crime|Drama|Horror|Mystery|Thriller  ...                270.0
# 453   Action|Adventure|Crime|Drama|Sci-Fi|Thriller  ...                394.0
# 473                          Comedy|Family|Fantasy  ...                 71.0
# ...                                            ...  ...                  ...
# 4683                 Drama|Fantasy|Sci-Fi|Thriller  ...                379.0
# 4688                        Animation|Comedy|Drama  ...                 82.0
# 4704                 Action|Adventure|Drama|Sci-Fi  ...                323.0
# 4752                                   Crime|Drama  ...                 59.0
# 4912                  Crime|Drama|Mystery|Thriller  ...                359.0
#
#      language  country  content_rating     budget  title_year  \
# 176   English      USA           TV-14  1500000.0         NaN
# 257   English      USA           TV-PG        NaN         NaN
# 398   English      USA           TV-14        NaN         NaN
# 453   English      USA           TV-MA        NaN         NaN
# 473   English      USA            TV-G        NaN         NaN
# ...       ...      ...             ...        ...         ...
# 4683  English      USA           TV-14        NaN         NaN
# 4688  English      USA           TV-PG        NaN         NaN
# 4704  English      USA           TV-14        NaN         NaN
# 4752  English       UK           TV-MA        NaN         NaN
# 4912  English      USA           TV-14        NaN         NaN
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 176                   321.0        7.5          1.33                    0
# 257                   554.0        7.6          4.00                    0
# 398                   183.0        8.6          1.78                59000
# 453                     4.0        8.8         16.00                55000
# 473                   960.0        7.6          4.00                    0
# ...                     ...        ...           ...                  ...
# 4683                  923.0        7.7         16.00                    0
# 4688                   11.0        8.2          1.33                  526
# 4704                  821.0        6.7         16.00                17000
# 4752                  340.0        8.5         16.00                10000
# 4912                  593.0        7.5         16.00                32000
#
# [102 rows x 28 columns]

# %%
movies.query('imdb_score.gt(7)')[['movie_title', 'title_year', 'director_name', 'imdb_score']].sort_values('imdb_score', ascending=False)
# Out:
#                          movie_title  title_year         director_name  \
# 2725                Towering Inferno         NaN        John Blanchard
# 1920        The Shawshank Redemption      1994.0        Frank Darabont
# 3402                   The Godfather      1972.0  Francis Ford Coppola
# 2779                         Dekalog         NaN                   NaN
# 4312            Kickboxer: Vengeance      2016.0        John Stockwell
# ...                              ...         ...                   ...
# 3657                            Race      2016.0       Stephen Hopkins
# 3638  The Return of the Pink Panther      1975.0         Blake Edwards
# 1957                Lords of Dogtown      2005.0   Catherine Hardwicke
# 127             Thor: The Dark World      2013.0           Alan Taylor
# 3948                   Human Traffic      1999.0       Justin Kerrigan
#
#       imdb_score
# 2725         9.5
# 1920         9.3
# 3402         9.2
# 2779         9.1
# 4312         9.1
# ...          ...
# 3657         7.1
# 3638         7.1
# 1957         7.1
# 127          7.1
# 3948         7.1
#
# [1546 rows x 4 columns]

# %%
fb_likes = movies.actor_1_facebook_likes

# %%
def debug_ser(ser):
    print("BEFORE")
    print(ser)
    print("AFTER")
    return ser

(fb_likes
.fillna(0)
 .pipe(debug_ser)
.astype(int)
 .head()
)
# Out:
# BEFORE
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64
# AFTER
# 0     1000
# 1    40000
# 2    11000
# 3    27000
# 4      131
# Name: actor_1_facebook_likes, dtype: int64

# %%
intermediate = None
def get_intermediate(ser):
    global intermediate
    intermediate = ser
    return ser

# %%
res = (
    fb_likes
    .fillna(0)
    .pipe(get_intermediate)
    .astype(int)
    .head()
)

# %%
intermediate
# Out:
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64

# %%
col_map = {
    "director_name": "director",
    "num_critic_for_reviews": "critic_reviews"
}

# %%
movies.rename(columns=col_map).head()
# Out:
#    color           director  critic_reviews  duration  \
# 0  Color      James Cameron           723.0     178.0
# 1  Color     Gore Verbinski           302.0     169.0
# 2  Color         Sam Mendes           602.0     148.0
# 3  Color  Christopher Nolan           813.0     164.0
# 4    NaN        Doug Walker             NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
idx_map = {
    "Avatar":"Ratava",
    "Spectre":"Ertceps",
    "Pirates of the Caribbean: At World's End":"POC",
}

# %%
col_map = {
    "aspect_ratio": "aspect",
    "movie_facebook_likes": "fblikes",
}

# %%
(
    movies.set_index("movie_title")
    .rename(index=idx_map, columns=col_map)
    .head(3)
)
# Out:
#              color   director_name  num_critic_for_reviews  duration  \
# movie_title
# Ratava       Color   James Cameron                   723.0     178.0
# POC          Color  Gore Verbinski                   302.0     169.0
# Ertceps      Color      Sam Mendes                   602.0     148.0
#
#              director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Ratava                           0.0                   855.0
# POC                            563.0                  1000.0
# Ertceps                          0.0                   161.0
#
#                  actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# Ratava       Joel David Moore                  1000.0  760505847.0
# POC             Orlando Bloom                 40000.0  309404152.0
# Ertceps          Rory Kinnear                 11000.0  200074175.0
#
#                                       genres  ... num_user_for_reviews  \
# movie_title                                   ...
# Ratava       Action|Adventure|Fantasy|Sci-Fi  ...               3054.0
# POC                 Action|Adventure|Fantasy  ...               1238.0
# Ertceps            Action|Adventure|Thriller  ...                994.0
#
#              language  country content_rating       budget title_year  \
# movie_title
# Ratava        English      USA          PG-13  237000000.0     2009.0
# POC           English      USA          PG-13  300000000.0     2007.0
# Ertceps       English       UK          PG-13  245000000.0     2015.0
#
#             actor_2_facebook_likes  imdb_score aspect fblikes
# movie_title
# Ratava                       936.0         7.9   1.78   33000
# POC                         5000.0         7.1   2.35       0
# Ertceps                      393.0         6.8   2.35   85000
#
# [3 rows x 27 columns]

# %%
movies = pd.read_csv(movies_url, index_col="movie_title")
ids = movies.index.to_list()
columns = movies.columns.to_list()

# %%
ids[0] = "Ratava"
ids[1] = "POC"
ids[2] = "Ertceps"
columns[1] = "director"
columns[-2] = "aspect"
columns[-1] = "fblikes"

# %%
movies.index = ids

# %%
movies.columns = columns

# %%
movies.head(3)
# Out:
#          color        director  num_critic_for_reviews  duration  \
# Ratava   Color   James Cameron                   723.0     178.0
# POC      Color  Gore Verbinski                   302.0     169.0
# Ertceps  Color      Sam Mendes                   602.0     148.0
#
#          director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# Ratava                       0.0                   855.0  Joel David Moore
# POC                        563.0                  1000.0     Orlando Bloom
# Ertceps                      0.0                   161.0      Rory Kinnear
#
#          actor_1_facebook_likes        gross                           genres  \
# Ratava                   1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# POC                     40000.0  309404152.0         Action|Adventure|Fantasy
# Ertceps                 11000.0  200074175.0        Action|Adventure|Thriller
#
#          ... num_user_for_reviews  language  country content_rating  \
# Ratava   ...               3054.0   English      USA          PG-13
# POC      ...               1238.0   English      USA          PG-13
# Ertceps  ...                994.0   English       UK          PG-13
#
#               budget title_year actor_2_facebook_likes  imdb_score aspect  \
# Ratava   237000000.0     2009.0                  936.0         7.9   1.78
# POC      300000000.0     2007.0                 5000.0         7.1   2.35
# Ertceps  245000000.0     2015.0                  393.0         6.8   2.35
#
#         fblikes
# Ratava    33000
# POC           0
# Ertceps   85000
#
# [3 rows x 27 columns]

# %%
def to_clean(val):
    return val.strip().lower().replace(" ", "_")

# %%
movies.rename(columns=to_clean).head(3)
# Out:
#          color        director  num_critic_for_reviews  duration  \
# Ratava   Color   James Cameron                   723.0     178.0
# POC      Color  Gore Verbinski                   302.0     169.0
# Ertceps  Color      Sam Mendes                   602.0     148.0
#
#          director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# Ratava                       0.0                   855.0  Joel David Moore
# POC                        563.0                  1000.0     Orlando Bloom
# Ertceps                      0.0                   161.0      Rory Kinnear
#
#          actor_1_facebook_likes        gross                           genres  \
# Ratava                   1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# POC                     40000.0  309404152.0         Action|Adventure|Fantasy
# Ertceps                 11000.0  200074175.0        Action|Adventure|Thriller
#
#          ... num_user_for_reviews  language  country content_rating  \
# Ratava   ...               3054.0   English      USA          PG-13
# POC      ...               1238.0   English      USA          PG-13
# Ertceps  ...                994.0   English       UK          PG-13
#
#               budget title_year actor_2_facebook_likes  imdb_score aspect  \
# Ratava   237000000.0     2009.0                  936.0         7.9   1.78
# POC      300000000.0     2007.0                 5000.0         7.1   2.35
# Ertceps  245000000.0     2015.0                  393.0         6.8   2.35
#
#         fblikes
# Ratava    33000
# POC           0
# Ertceps   85000
#
# [3 rows x 27 columns]

# %%
cols = [
    col.strip().lower().replace(" ", "_")
    for col in movies.columns
]

# %%
movies.columns = cols

# %%
movies.head(3)
# Out:
#          color        director  num_critic_for_reviews  duration  \
# Ratava   Color   James Cameron                   723.0     178.0
# POC      Color  Gore Verbinski                   302.0     169.0
# Ertceps  Color      Sam Mendes                   602.0     148.0
#
#          director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# Ratava                       0.0                   855.0  Joel David Moore
# POC                        563.0                  1000.0     Orlando Bloom
# Ertceps                      0.0                   161.0      Rory Kinnear
#
#          actor_1_facebook_likes        gross                           genres  \
# Ratava                   1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# POC                     40000.0  309404152.0         Action|Adventure|Fantasy
# Ertceps                 11000.0  200074175.0        Action|Adventure|Thriller
#
#          ... num_user_for_reviews  language  country content_rating  \
# Ratava   ...               3054.0   English      USA          PG-13
# POC      ...               1238.0   English      USA          PG-13
# Ertceps  ...                994.0   English       UK          PG-13
#
#               budget title_year actor_2_facebook_likes  imdb_score aspect  \
# Ratava   237000000.0     2009.0                  936.0         7.9   1.78
# POC      300000000.0     2007.0                 5000.0         7.1   2.35
# Ertceps  245000000.0     2015.0                  393.0         6.8   2.35
#
#         fblikes
# Ratava    33000
# POC           0
# Ertceps   85000
#
# [3 rows x 27 columns]

# %%
movies = pd.read_csv(movies_url)

# %%
idx_map
# Out:
# {'Avatar': 'Ratava',
#  'Spectre': 'Ertceps',
#  "Pirates of the Caribbean: At World's End": 'POC'}

# %%
col_map
# Out:
# {'aspect_ratio': 'aspect', 'movie_facebook_likes': 'fblikes'}

# %%
(
    movies
    .rename(index=idx_map, columns=col_map)
    .assign(has_seen=0)
)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... language country  content_rating       budget title_year  \
# 0     ...  English     USA           PG-13  237000000.0     2009.0
# 1     ...  English     USA           PG-13  300000000.0     2007.0
# 2     ...  English      UK           PG-13  245000000.0     2015.0
# 3     ...  English     USA           PG-13  250000000.0     2012.0
# 4     ...      NaN     NaN             NaN          NaN        NaN
# ...   ...      ...     ...             ...          ...        ...
# 4911  ...  English  Canada             NaN          NaN     2013.0
# 4912  ...  English     USA           TV-14          NaN        NaN
# 4913  ...  English     USA             NaN       1400.0     2013.0
# 4914  ...  English     USA           PG-13          NaN     2012.0
# 4915  ...  English     USA              PG       1100.0     2004.0
#
#       actor_2_facebook_likes imdb_score aspect  fblikes has_seen
# 0                      936.0        7.9   1.78    33000        0
# 1                     5000.0        7.1   2.35        0        0
# 2                      393.0        6.8   2.35    85000        0
# 3                    23000.0        8.5   2.35   164000        0
# 4                       12.0        7.1    NaN        0        0
# ...                      ...        ...    ...      ...      ...
# 4911                   470.0        7.7    NaN       84        0
# 4912                   593.0        7.5  16.00    32000        0
# 4913                     0.0        6.3    NaN       16        0
# 4914                   719.0        6.3   2.35      660        0
# 4915                    23.0        6.6   1.85      456        0
#
# [4916 rows x 29 columns]

# %%
cols = [
    "actor_1_facebook_likes",
    "actor_2_facebook_likes",
    "actor_3_facebook_likes",
    "director_facebook_likes",
]

# %%
sum_col = movies.loc[:, cols].sum(axis="columns")

# %%
sum_col.head()
# Out:
# 0     2791.0
# 1    46563.0
# 2    11554.0
# 3    95000.0
# 4      274.0
# dtype: float64

# %%
movies.assign(total_likes = sum_col).head(5)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   language country  content_rating       budget title_year  \
# 0  English     USA           PG-13  237000000.0     2009.0
# 1  English     USA           PG-13  300000000.0     2007.0
# 2  English      UK           PG-13  245000000.0     2015.0
# 3  English     USA           PG-13  250000000.0     2012.0
# 4      NaN     NaN             NaN          NaN        NaN
#
#    actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                   936.0        7.9         1.78                 33000
# 1                  5000.0        7.1         2.35                     0
# 2                   393.0        6.8         2.35                 85000
# 3                 23000.0        8.5         2.35                164000
# 4                    12.0        7.1          NaN                     0
#
#   total_likes
# 0      2791.0
# 1     46563.0
# 2     11554.0
# 3     95000.0
# 4       274.0
#
# [5 rows x 29 columns]

# %%
def sum_likes(df_):
    return df_[
    [
        c
        for c in df_.columns
        if "like" in c
        and ("actor" in c or "director" in c)
    ]
    ].sum(axis=1)

# %%
movies.assign(total_likes=sum_likes).head(5)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   language country  content_rating       budget title_year  \
# 0  English     USA           PG-13  237000000.0     2009.0
# 1  English     USA           PG-13  300000000.0     2007.0
# 2  English      UK           PG-13  245000000.0     2015.0
# 3  English     USA           PG-13  250000000.0     2012.0
# 4      NaN     NaN             NaN          NaN        NaN
#
#    actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                   936.0        7.9         1.78                 33000
# 1                  5000.0        7.1         2.35                     0
# 2                   393.0        6.8         2.35                 85000
# 3                 23000.0        8.5         2.35                164000
# 4                    12.0        7.1          NaN                     0
#
#   total_likes
# 0      2791.0
# 1     46563.0
# 2     11554.0
# 3     95000.0
# 4       274.0
#
# [5 rows x 29 columns]

# %%
sum_likes(movies).isna().sum()
# Out:
# 0

# %%
def cast_like_gt_actor(df_):
    return (
        df_["cast_total_facebook_likes"]
        >= df_["total_likes"]
    )

# %%
total = (
movies["actor_1_facebook_likes"]
 + movies["actor_2_facebook_likes"]
 + movies["actor_3_facebook_likes"]
 + movies["director_facebook_likes"]
 )

# %%
df2 = movies.assign(
    total_likes=total,
    is_cast_likes_more=cast_like_gt_actor,
)

# %%
df2["is_cast_likes_more"].all()
# Out:
# False

# %%
df2 = df2.drop(columns="total_likes")

# %%
actor_sum = movies[[
    c
    for c in movies.columns
    if "actor" in c and "_likes" in c
]].sum(axis="columns")

# %%
actor_sum.head(5)
# Out:
# 0     2791.0
# 1    46000.0
# 2    11554.0
# 3    73000.0
# 4      143.0
# dtype: float64

# %%
movies.cast_total_facebook_likes.ge(actor_sum).all()
# Out:
# True

# %%
pct_like = actor_sum.div(
    movies.cast_total_facebook_likes
).mul(100)

# %%
pct_like.describe()
# Out:
# count    4883.000000
# mean       83.327889
# std        14.056578
# min        30.076696
# 25%        73.528368
# 50%        86.928884
# 75%        95.477440
# max       100.000000
# dtype: float64

# %%
#12 on page 42 (63 of 627 of PDF)
